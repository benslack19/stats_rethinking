# %% [markdown]
# --
# title: Multilevel modeling with a random slope
# mathjax: True
# --
#
# In [my last post], I gave an example of a multilevel model using a binomial generalized linear model (GLM). It described the use of varying intercepts, which is the simplest kind of multilevel model (AKA mixed effects, random effects, varying effects model).

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm
import scipy.stats as stats
import seaborn as sns
from scipy.special import expit as logistic
from scipy.special import logit
from scipy.optimize import curve_fit
import daft
from causalgraphicalmodels import CausalGraphicalModel
from theano import tensor as tt

# %%
# %load_ext nb_black
# %config InlineBackend.figure_format = 'retina'
# %load_ext watermark
RANDOM_SEED = 8927
np.random.seed(RANDOM_SEED)
az.style.use("arviz-darkgrid")
az.rcParams["stats.hdi_prob"] = 0.89  # sets default credible interval used by arviz
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark

# %%
sns.set_context("talk")

# %%
def standardize(x):
    x = (x - np.mean(x)) / np.std(x)
    return x

# %% [markdown]
# # Problem description
#
# Let’s revisit the Bangladesh fertility data, `data(bangladesh)`. Fit a model with both varying intercepts by `district_id` and varying slopes of `urban` by `district_id`. You are still predicting `use.contraception`. Inspect the correlation between the intercepts and slopes. Can you interpret this correlation, in terms of what it tells you about the pattern of contraceptive use in the sample?
#
# It might help to plot the mean (or median) varying effect estimates for both the intercepts and slopes, by district. Then you can visualize the correlation and maybe more easily think through what it means to have a particular correlation. Plotting predicted proportion of women using contraception, with urban women on one axis and rural on the other, might also help.

# %% [markdown]
# I was unsure what "varying slopes of urban by `district_id`" meant so I inspected the table.

# %% [markdown]
# # Data exploration and setup

# %%
df_bangladesh = pd.read_csv(
    "../pymc3_ed_resources/resources/Rethinking/Data/bangladesh.csv",
    delimiter=";",
)
df_bangladesh.head()
# Out:
#    woman  district  use.contraception  living.children  age.centered  urban
# 0      1         1                  0                4       18.4400      1
# 1      2         1                  0                1       -5.5599      1
# 2      3         1                  0                3        1.4400      1
# 3      4         1                  0                4        8.4400      1
# 4      5         1                  0                1      -13.5590      1

# %%
print("shape of df: ", df_bangladesh.shape)
# Out:
# shape of df:  (1934, 6)

# %% [markdown]
# Per the homework, fix the district variable since it is not a contiguous set of integers.. Luckily, this is easy enough to do with `pd.Categorical`.

# %%
df_bangladesh["district_code"] = pd.Categorical(df_bangladesh["district"]).codes

# %%
# inspect and see that it's now 0-indexed for Python

print(
    "df head: ", df_bangladesh[["district", "district_code"]].drop_duplicates().head()
)

# and also that it accounts for missing district 54
print(
    "df tail: ", df_bangladesh[["district", "district_code"]].drop_duplicates().tail(10)
)
# Out:
# df head:       district  district_code
# 0           1              0
# 117         2              1
# 137         3              2
# 139         4              3
# 169         5              4
# df tail:        district  district_code
# 1622        51             50
# 1659        52             51
# 1720        53             52
# 1739        55             53
# 1745        56             54
# 1790        57             55
# 1817        58             56
# 1850        59             57
# 1860        60             58
# 1892        61             59

# %%
# Look outcome variable
df_bangladesh["use.contraception"].value_counts()
# Out:
# 0    1175
# 1     759
# Name: use.contraception, dtype: int64

# %%
df_bangladesh.head()
# Out:
#    woman  district  use.contraception  living.children  age.centered  urban  \
# 0      1         1                  0                4       18.4400      1
# 1      2         1                  0                1       -5.5599      1
# 2      3         1                  0                3        1.4400      1
# 3      4         1                  0                4        8.4400      1
# 4      5         1                  0                1      -13.5590      1
#
#    district_code
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df_bangladesh[["district_code", "urban"]].drop_duplicates().sort_values(
    by=["district_code", "urban"]
)
# Out:
#       district_code  urban
# 63                0      0
# 0                 0      1
# 117               1      0
# 137               2      1
# 150               3      0
# ...             ...    ...
# 1850             57      0
# 1870             58      0
# 1860             58      1
# 1903             59      0
# 1892             59      1
#
# [102 rows x 2 columns]

# %% [markdown]
# `Urban` is a categorical index variable which states whether that woman lives in an urban part of that district. From inspection of Chapter 14 code, the setup is similar (R code 14.10 to 14.13).

# %% [markdown]
# # Model equation to include varying slopes
#
# This problem is conceptually similar to Chapter 14's cafe example. I'll use that as a template for this problem. One difference though is that this problem has a Binomial likelihood while the cafe problem had a Normal likelihood. I think all we have to change, however, is that we use a link function.

# %% [markdown]
# **Model `mvse` equation**
#
# $$C_i \sim \text{Binomial}(1, p_i) \tag{likelihood}$$
#
# $$\text{logit}(p_i) = \alpha_{\text{district}[i]} + \beta_{\text{district}[i]}U_{[i]} \tag{linear model with link function}$$
#
# Matrix of varying intercepts and slopes and its covariance matrix:
#
#
# $$\begin{bmatrix}\alpha_{\text{district}} \\ \beta_{\text{district}} \end{bmatrix} \text { ~ MVNormal } \left( \begin{bmatrix}\alpha \\ \beta \end{bmatrix} , \text{S} \right)  \tag{population of varying effects} $$
#
# In this prior, we have an intercept term for each district (average contraception use in rural only because of the slope term when U is 0) and the slope (how much it changes if a woman lives in an urban district). (This is different from problem 13H1 where the intercept term represents average across the whole district, regardless of whether it's urban or rural.) Instead of having separate lines for the prior, we put them in the same multivariate normal covariance matrix to allow information sharing between slopes and priors. This allows adaptive regularization of individual district intercepts, their slopes, and the correlation among them.
#
# The covariance matrix **S** is defined here. (Note: The top left of each array is isn't showing up correctly. It should be \(\sigma_{\alpha}\).)
#
# $$ \text{S} = \left(\begin{array} \sigma_{\alpha} & 0 \\ 0 & \sigma_{\beta} \end{array}\right)  \text{R} \left(\begin{array} \sigma_{\alpha} & 0 \\ 0 & \sigma_{\beta} \end{array}\right) \tag{construct covariance matrix} $$
#
# Why is the covariance matrix set up with separate standard deviations and a correlation matrix? way? Per the text, "splitting the covaraince up into standard deviations and correlations... [will make it] easier to later understand the inferred structure of the varying effects."

# %% [markdown]
# Here are the hyperprriors and priors that define the adaptive varying effects prior. In contrast to the cafe example, I'll choose slightly wider prior for \(\beta\), with normal distribution centered around 0 to be a bit more naive to the expected results. My \(\alpha\) will be the same as above. Note also that since we're not using a Normal likelihood, there's no \(\sigma\) term that would be a part of it. We still have the sigmas associated with the alpha and beta in the covariance matrix.
#
# $$ \alpha \text { ~ Normal}(0, 1.5) \tag{prior for average intercept} $$
# $$ \beta \text { ~ Normal}(0, 2)  \tag{prior for average slope} $$
# $$ \sigma_{alpha} \text{ ~ Exponential}(1) \tag{prior sddev among intercepts} $$
# $$ \sigma_{beta} \text{ ~ Exponential}(1) \tag{prior sddev among slopes} $$
# $$ \text{R ~ LKJcorr}(2) \tag{prior for correlation matrix} $$
#
# LKJcorr can be thought of as a "regularizing prior for correlation matrices". The LKJcorr's parameter is eta and per the text a value of 2 provides a pretty wide distribution of possible correlations centered over 0 (Figure 14.3).

# %%
N_districts = len(df_bangladesh["district_code"].unique())

# %%
df_bangladesh.head()
# Out:
#    woman  district  use.contraception  living.children  age.centered  urban  \
# 0      1         1                  0                4       18.4400      1
# 1      2         1                  0                1       -5.5599      1
# 2      3         1                  0                3        1.4400      1
# 3      4         1                  0                4        8.4400      1
# 4      5         1                  0                1      -13.5590      1
#
#    district_code
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
# Used this below
from theano import tensor as tt

# %%
# code modified from repo and adapted for binomial likelihood

with pm.Model() as mvse:
    # LKJCholeskyCov is more efficient than LKJCorr
    # PyMC >= 3.9 extracts the stds and matrix of correlations automatically for us
    chol, Rho_, sigma_district = pm.LKJCholeskyCov(
        "chol_cov", n=2, eta=2, sd_dist=pm.Exponential.dist(1.0), compute_corr=True
    )

    a = pm.Normal("a", mu=0, sd=1.5)  # used same from previous problem
    b = pm.Normal("b", mu=0, sd=2)  # use something conservative

    ab_district = pm.MvNormal(
        "ab_district", mu=tt.stack([a, b]), chol=chol, shape=(N_districts, 2)
    )  # population of varying effects
    # shape needs to be (N_districts, 2) because we're getting back both a and b for each district

    # originally written link function
    # prevented p from being included as a parameter I could access in posterior distribution
    #     p = pm.math.invlogit(
    #         ab_district[df_bangladesh["district_code"], 0]
    #         + ab_district[df_bangladesh["district_code"], 1] * df_bangladesh["urban"]
    #     )

    # link function
    p = pm.Deterministic(
        "p",
        pm.math.invlogit(
            ab_district[df_bangladesh["district_code"], 0]
            + ab_district[df_bangladesh["district_code"], 1] * df_bangladesh["urban"]
        ),
    )

    # likelihood, n=1 since each represents an individual woman
    c = pm.Binomial("c", n=1, p=p, observed=df_bangladesh["use.contraception"])

    trace_mvse = pm.sample(draws=1000, random_seed=19, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO:pymc3:Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# INFO:pymc3:Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [ab_district, b, a, chol_cov]
# INFO:pymc3:NUTS: [ab_district, b, a, chol_cov]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 01:16<00:00 Sampling 4 chains, 1 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 88 seconds.
# INFO:pymc3:Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 88 seconds.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 10% for some parameters.
# WARNING:pymc3:The number of effective samples is smaller than 10% for some parameters.

# %%
az.summary(trace_mvse)
# Out:
# /Users/blacar/opt/anaconda3/envs/stats_rethinking/lib/python3.8/site-packages/arviz/stats/diagnostics.py:642: RuntimeWarning: invalid value encountered in double_scalars
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                    mean     sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# a                -0.710  0.101    -0.879     -0.555      0.002    0.001
# b                 0.709  0.173     0.424      0.970      0.004    0.003
# ab_district[0,0] -1.542  0.316    -2.051     -1.045      0.006    0.004
# ab_district[0,1]  1.066  0.391     0.420      1.657      0.007    0.005
# ab_district[1,0] -0.677  0.371    -1.296     -0.103      0.006    0.005
# ...                 ...    ...       ...        ...        ...      ...
# p[1929]           0.240  0.063     0.132      0.330      0.001    0.001
# p[1930]           0.240  0.063     0.132      0.330      0.001    0.001
# p[1931]           0.240  0.063     0.132      0.330      0.001    0.001
# p[1932]           0.240  0.063     0.132      0.330      0.001    0.001
# p[1933]           0.240  0.063     0.132      0.330      0.001    0.001
#
#                   ess_mean  ess_sd  ess_bulk  ess_tail  r_hat
# a                   2554.0  2550.0    2556.0    2752.0    1.0
# b                   1770.0  1770.0    1771.0    2402.0    1.0
# ab_district[0,0]    3243.0  3123.0    3293.0    2857.0    1.0
# ab_district[0,1]    2826.0  2550.0    2868.0    2751.0    1.0
# ab_district[1,0]    3652.0  2732.0    3686.0    2544.0    1.0
# ...                    ...     ...       ...       ...    ...
# p[1929]             3924.0  3701.0    3912.0    2549.0    1.0
# p[1930]             3924.0  3701.0    3912.0    2549.0    1.0
# p[1931]             3924.0  3701.0    3912.0    2549.0    1.0
# p[1932]             3924.0  3701.0    3912.0    2549.0    1.0
# p[1933]             3924.0  3701.0    3912.0    2549.0    1.0
#
# [2065 rows x 11 columns]

# %% [markdown]
# # Inspection of correlation between slopes and prior
#
# This will tell us whether living in an urban area would influence the likelihood of taking contraception. A positive correlation would tell us that across all districts with an already high average probability of taking contraception (high slopes), even more would take contraception in an urban area (high intercept). If the correlation were negative, that means women living in districts with high average probability would be *less likely* to take contraception if they were in an urban area.

# %% [markdown]
# Let's plot the intercepts and slopes to see what the relationship looks like. First, let's see where we can find these values in the parameters.

# %%
az.summary(trace_mvse, var_names="ab_district").index
# Out:
# Index(['ab_district[0,0]', 'ab_district[0,1]', 'ab_district[1,0]',
#        'ab_district[1,1]', 'ab_district[2,0]', 'ab_district[2,1]',
#        'ab_district[3,0]', 'ab_district[3,1]', 'ab_district[4,0]',
#        'ab_district[4,1]',
#        ...
#        'ab_district[55,0]', 'ab_district[55,1]', 'ab_district[56,0]',
#        'ab_district[56,1]', 'ab_district[57,0]', 'ab_district[57,1]',
#        'ab_district[58,0]', 'ab_district[58,1]', 'ab_district[59,0]',
#        'ab_district[59,1]'],
#       dtype='object', length=120)

# %% [markdown]
# It looks like the district is represented in the 0th position of the index and there's two terms associate with each. The first term is the alpha term (intercepts) and the second term is the beta term (slopes). We'll plot the means of these parameters with intercepts in a scatter plot.

# %%
# Let's turn it into a dataframe for plotting
df_ab_district = az.summary(trace_mvse, var_names="ab_district")
df_ab_district.head()
# Out:
#                    mean     sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# ab_district[0,0] -1.542  0.316    -2.051     -1.045      0.006    0.004
# ab_district[0,1]  1.066  0.391     0.420      1.657      0.007    0.005
# ab_district[1,0] -0.677  0.371    -1.296     -0.103      0.006    0.005
# ab_district[1,1]  0.686  0.672    -0.350      1.775      0.011    0.009
# ab_district[2,0] -0.686  0.583    -1.579      0.221      0.010    0.008
#
#                   ess_mean  ess_sd  ess_bulk  ess_tail  r_hat
# ab_district[0,0]    3243.0  3123.0    3293.0    2857.0    1.0
# ab_district[0,1]    2826.0  2550.0    2868.0    2751.0    1.0
# ab_district[1,0]    3652.0  2732.0    3686.0    2544.0    1.0
# ab_district[1,1]    3832.0  2573.0    3811.0    2866.0    1.0
# ab_district[2,0]    3254.0  2808.0    3264.0    2690.0    1.0

# %%
# Can add concentric circles later
f, ax1 = plt.subplots(1, 1, figsize=(6, 4))
for i in range(60):
    ax1.scatter(
        df_ab_district.loc["ab_district[" + str(i) + ",0]", "mean"],
        df_ab_district.loc["ab_district[" + str(i) + ",1]", "mean"],
        facecolors="none",
        edgecolors="black",
    )

ax1.set(
    xlabel="intercepts (a_district)",
    ylabel="slopes (b_district)",
    title="intercepts vs. slopes",
)
# Out:
# [Text(0.5, 0, 'intercepts (a_district)'),
#  Text(0, 0.5, 'slopes (b_district)'),
#  Text(0.5, 1.0, 'intercepts vs. slopes')]

# %% [markdown]
# We see a negative correlation, which is also confirmed by inspecting the posterior distribution for the value for rho in the Cholevsky correlation matrix.

# %%
# Inspect off-diagonal values
az.summary(trace_mvse, var_names="chol_cov_corr")
# Out:
# /Users/blacar/opt/anaconda3/envs/stats_rethinking/lib/python3.8/site-packages/arviz/stats/diagnostics.py:642: RuntimeWarning: invalid value encountered in double_scalars
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                      mean     sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# chol_cov_corr[0,0]  1.000  0.000     1.000      1.000      0.000    0.000
# chol_cov_corr[0,1] -0.654  0.167    -0.905     -0.432      0.006    0.004
# chol_cov_corr[1,0] -0.654  0.167    -0.905     -0.432      0.006    0.004
# chol_cov_corr[1,1]  1.000  0.000     1.000      1.000      0.000    0.000
#
#                     ess_mean  ess_sd  ess_bulk  ess_tail  r_hat
# chol_cov_corr[0,0]    4000.0  4000.0    4000.0    4000.0    NaN
# chol_cov_corr[0,1]     703.0   703.0     691.0    1231.0    1.0
# chol_cov_corr[1,0]     703.0   703.0     691.0    1231.0    1.0
# chol_cov_corr[1,1]    4000.0  4000.0    3979.0    3973.0    1.0

# %% [markdown]
# Let's plot the prior and posterior distribution of the correlation between intercepts and slopes.

# %%
trace_mvse_df = trace_mvse.to_dataframe()

# %%
[print(col) for col in trace_mvse_df.columns]
# Out:
# chain
# draw
# ('posterior', 'a')
# ('posterior', 'b')
# ('posterior', 'ab_district[0,0]', 0, 0)
# ('posterior', 'ab_district[0,1]', 0, 1)
# ('posterior', 'ab_district[1,0]', 1, 0)
# ('posterior', 'ab_district[1,1]', 1, 1)
# ('posterior', 'ab_district[10,0]', 10, 0)
# ('posterior', 'ab_district[10,1]', 10, 1)
# ('posterior', 'ab_district[11,0]', 11, 0)
# ('posterior', 'ab_district[11,1]', 11, 1)
# ('posterior', 'ab_district[12,0]', 12, 0)
# ('posterior', 'ab_district[12,1]', 12, 1)
# ('posterior', 'ab_district[13,0]', 13, 0)
# ('posterior', 'ab_district[13,1]', 13, 1)
# ('posterior', 'ab_district[14,0]', 14, 0)
# ('posterior', 'ab_district[14,1]', 14, 1)
# ('posterior', 'ab_district[15,0]', 15, 0)
# ('posterior', 'ab_district[15,1]', 15, 1)
# ('posterior', 'ab_district[16,0]', 16, 0)
# ('posterior', 'ab_district[16,1]', 16, 1)
# ('posterior', 'ab_district[17,0]', 17, 0)
# ('posterior', 'ab_district[17,1]', 17, 1)
# ('posterior', 'ab_district[18,0]', 18, 0)
# ('posterior', 'ab_district[18,1]', 18, 1)
# ('posterior', 'ab_district[19,0]', 19, 0)
# ('posterior', 'ab_district[19,1]', 19, 1)
# ('posterior', 'ab_district[2,0]', 2, 0)
# ('posterior', 'ab_district[2,1]', 2, 1)
# ('posterior', 'ab_district[20,0]', 20, 0)
# ('posterior', 'ab_district[20,1]', 20, 1)
# ('posterior', 'ab_district[21,0]', 21, 0)
# ('posterior', 'ab_district[21,1]', 21, 1)
# ('posterior', 'ab_district[22,0]', 22, 0)
# ('posterior', 'ab_district[22,1]', 22, 1)
# ('posterior', 'ab_district[23,0]', 23, 0)
# ('posterior', 'ab_district[23,1]', 23, 1)
# ('posterior', 'ab_district[24,0]', 24, 0)
# ('posterior', 'ab_district[24,1]', 24, 1)
# ('posterior', 'ab_district[25,0]', 25, 0)
# ('posterior', 'ab_district[25,1]', 25, 1)
# ('posterior', 'ab_district[26,0]', 26, 0)
# ('posterior', 'ab_district[26,1]', 26, 1)
# ('posterior', 'ab_district[27,0]', 27, 0)
# ('posterior', 'ab_district[27,1]', 27, 1)
# ('posterior', 'ab_district[28,0]', 28, 0)
# ('posterior', 'ab_district[28,1]', 28, 1)
# ('posterior', 'ab_district[29,0]', 29, 0)
# ('posterior', 'ab_district[29,1]', 29, 1)
# ('posterior', 'ab_district[3,0]', 3, 0)
# ('posterior', 'ab_district[3,1]', 3, 1)
# ('posterior', 'ab_district[30,0]', 30, 0)
# ('posterior', 'ab_district[30,1]', 30, 1)
# ('posterior', 'ab_district[31,0]', 31, 0)
# ('posterior', 'ab_district[31,1]', 31, 1)
# ('posterior', 'ab_district[32,0]', 32, 0)
# ('posterior', 'ab_district[32,1]', 32, 1)
# ('posterior', 'ab_district[33,0]', 33, 0)
# ('posterior', 'ab_district[33,1]', 33, 1)
# ('posterior', 'ab_district[34,0]', 34, 0)
# ('posterior', 'ab_district[34,1]', 34, 1)
# ('posterior', 'ab_district[35,0]', 35, 0)
# ('posterior', 'ab_district[35,1]', 35, 1)
# ('posterior', 'ab_district[36,0]', 36, 0)
# ('posterior', 'ab_district[36,1]', 36, 1)
# ('posterior', 'ab_district[37,0]', 37, 0)
# ('posterior', 'ab_district[37,1]', 37, 1)
# ('posterior', 'ab_district[38,0]', 38, 0)
# ('posterior', 'ab_district[38,1]', 38, 1)
# ('posterior', 'ab_district[39,0]', 39, 0)
# ('posterior', 'ab_district[39,1]', 39, 1)
# ('posterior', 'ab_district[4,0]', 4, 0)
# ('posterior', 'ab_district[4,1]', 4, 1)
# ('posterior', 'ab_district[40,0]', 40, 0)
# ('posterior', 'ab_district[40,1]', 40, 1)
# ('posterior', 'ab_district[41,0]', 41, 0)
# ('posterior', 'ab_district[41,1]', 41, 1)
# ('posterior', 'ab_district[42,0]', 42, 0)
# ('posterior', 'ab_district[42,1]', 42, 1)
# ('posterior', 'ab_district[43,0]', 43, 0)
# ('posterior', 'ab_district[43,1]', 43, 1)
# ('posterior', 'ab_district[44,0]', 44, 0)
# ('posterior', 'ab_district[44,1]', 44, 1)
# ('posterior', 'ab_district[45,0]', 45, 0)
# ('posterior', 'ab_district[45,1]', 45, 1)
# ('posterior', 'ab_district[46,0]', 46, 0)
# ('posterior', 'ab_district[46,1]', 46, 1)
# ('posterior', 'ab_district[47,0]', 47, 0)
# ('posterior', 'ab_district[47,1]', 47, 1)
# ('posterior', 'ab_district[48,0]', 48, 0)
# ('posterior', 'ab_district[48,1]', 48, 1)
# ('posterior', 'ab_district[49,0]', 49, 0)
# ('posterior', 'ab_district[49,1]', 49, 1)
# ('posterior', 'ab_district[5,0]', 5, 0)
# ('posterior', 'ab_district[5,1]', 5, 1)
# ('posterior', 'ab_district[50,0]', 50, 0)
# ('posterior', 'ab_district[50,1]', 50, 1)
# ('posterior', 'ab_district[51,0]', 51, 0)
# ('posterior', 'ab_district[51,1]', 51, 1)
# ('posterior', 'ab_district[52,0]', 52, 0)
# ('posterior', 'ab_district[52,1]', 52, 1)
# ('posterior', 'ab_district[53,0]', 53, 0)
# ('posterior', 'ab_district[53,1]', 53, 1)
# ('posterior', 'ab_district[54,0]', 54, 0)
# ('posterior', 'ab_district[54,1]', 54, 1)
# ('posterior', 'ab_district[55,0]', 55, 0)
# ('posterior', 'ab_district[55,1]', 55, 1)
# ('posterior', 'ab_district[56,0]', 56, 0)
# ('posterior', 'ab_district[56,1]', 56, 1)
# ('posterior', 'ab_district[57,0]', 57, 0)
# ('posterior', 'ab_district[57,1]', 57, 1)
# ('posterior', 'ab_district[58,0]', 58, 0)
# ('posterior', 'ab_district[58,1]', 58, 1)
# ('posterior', 'ab_district[59,0]', 59, 0)
# ('posterior', 'ab_district[59,1]', 59, 1)
# ('posterior', 'ab_district[6,0]', 6, 0)
# ('posterior', 'ab_district[6,1]', 6, 1)
# ('posterior', 'ab_district[7,0]', 7, 0)
# ('posterior', 'ab_district[7,1]', 7, 1)
# ('posterior', 'ab_district[8,0]', 8, 0)
# ('posterior', 'ab_district[8,1]', 8, 1)
# ('posterior', 'ab_district[9,0]', 9, 0)
# ('posterior', 'ab_district[9,1]', 9, 1)
# ('posterior', 'chol_cov[0]', 0)
# ('posterior', 'chol_cov[1]', 1)
# ('posterior', 'chol_cov[2]', 2)
# ('posterior', 'chol_cov_stds[0]', 0)
# ('posterior', 'chol_cov_stds[1]', 1)
# ('posterior', 'chol_cov_corr[0,0]', 0, 0)
# ('posterior', 'chol_cov_corr[0,1]', 0, 1)
# ('posterior', 'chol_cov_corr[1,0]', 1, 0)
# ('posterior', 'chol_cov_corr[1,1]', 1, 1)
# ('posterior', 'p[0]', 0)
# ('posterior', 'p[1000]', 1000)
# ('posterior', 'p[1001]', 1001)
# ('posterior', 'p[1002]', 1002)
# ('posterior', 'p[1003]', 1003)
# ('posterior', 'p[1004]', 1004)
# ('posterior', 'p[1005]', 1005)
# ('posterior', 'p[1006]', 1006)
# ('posterior', 'p[1007]', 1007)
# ('posterior', 'p[1008]', 1008)
# ('posterior', 'p[1009]', 1009)
# ('posterior', 'p[100]', 100)
# ('posterior', 'p[1010]', 1010)
# ('posterior', 'p[1011]', 1011)
# ('posterior', 'p[1012]', 1012)
# ('posterior', 'p[1013]', 1013)
# ('posterior', 'p[1014]', 1014)
# ('posterior', 'p[1015]', 1015)
# ('posterior', 'p[1016]', 1016)
# ('posterior', 'p[1017]', 1017)
# ('posterior', 'p[1018]', 1018)
# ('posterior', 'p[1019]', 1019)
# ('posterior', 'p[101]', 101)
# ('posterior', 'p[1020]', 1020)
# ('posterior', 'p[1021]', 1021)
# ('posterior', 'p[1022]', 1022)
# ('posterior', 'p[1023]', 1023)
# ('posterior', 'p[1024]', 1024)
# ('posterior', 'p[1025]', 1025)
# ('posterior', 'p[1026]', 1026)
# ('posterior', 'p[1027]', 1027)
# ('posterior', 'p[1028]', 1028)
# ('posterior', 'p[1029]', 1029)
# ('posterior', 'p[102]', 102)
# ('posterior', 'p[1030]', 1030)
# ('posterior', 'p[1031]', 1031)
# ('posterior', 'p[1032]', 1032)
# ('posterior', 'p[1033]', 1033)
# ('posterior', 'p[1034]', 1034)
# ('posterior', 'p[1035]', 1035)
# ('posterior', 'p[1036]', 1036)
# ('posterior', 'p[1037]', 1037)
# ('posterior', 'p[1038]', 1038)
# ('posterior', 'p[1039]', 1039)
# ('posterior', 'p[103]', 103)
# ('posterior', 'p[1040]', 1040)
# ('posterior', 'p[1041]', 1041)
# ('posterior', 'p[1042]', 1042)
# ('posterior', 'p[1043]', 1043)
# ('posterior', 'p[1044]', 1044)
# ('posterior', 'p[1045]', 1045)
# ('posterior', 'p[1046]', 1046)
# ('posterior', 'p[1047]', 1047)
# ('posterior', 'p[1048]', 1048)
# ('posterior', 'p[1049]', 1049)
# ('posterior', 'p[104]', 104)
# ('posterior', 'p[1050]', 1050)
# ('posterior', 'p[1051]', 1051)
# ('posterior', 'p[1052]', 1052)
# ('posterior', 'p[1053]', 1053)
# ('posterior', 'p[1054]', 1054)
# ('posterior', 'p[1055]', 1055)
# ('posterior', 'p[1056]', 1056)
# ('posterior', 'p[1057]', 1057)
# ('posterior', 'p[1058]', 1058)
# ('posterior', 'p[1059]', 1059)
# ('posterior', 'p[105]', 105)
# ('posterior', 'p[1060]', 1060)
# ('posterior', 'p[1061]', 1061)
# ('posterior', 'p[1062]', 1062)
# ('posterior', 'p[1063]', 1063)
# ('posterior', 'p[1064]', 1064)
# ('posterior', 'p[1065]', 1065)
# ('posterior', 'p[1066]', 1066)
# ('posterior', 'p[1067]', 1067)
# ('posterior', 'p[1068]', 1068)
# ('posterior', 'p[1069]', 1069)
# ('posterior', 'p[106]', 106)
# ('posterior', 'p[1070]', 1070)
# ('posterior', 'p[1071]', 1071)
# ('posterior', 'p[1072]', 1072)
# ('posterior', 'p[1073]', 1073)
# ('posterior', 'p[1074]', 1074)
# ('posterior', 'p[1075]', 1075)
# ('posterior', 'p[1076]', 1076)
# ('posterior', 'p[1077]', 1077)
# ('posterior', 'p[1078]', 1078)
# ('posterior', 'p[1079]', 1079)
# ('posterior', 'p[107]', 107)
# ('posterior', 'p[1080]', 1080)
# ('posterior', 'p[1081]', 1081)
# ('posterior', 'p[1082]', 1082)
# ('posterior', 'p[1083]', 1083)
# ('posterior', 'p[1084]', 1084)
# ('posterior', 'p[1085]', 1085)
# ('posterior', 'p[1086]', 1086)
# ('posterior', 'p[1087]', 1087)
# ('posterior', 'p[1088]', 1088)
# ('posterior', 'p[1089]', 1089)
# ('posterior', 'p[108]', 108)
# ('posterior', 'p[1090]', 1090)
# ('posterior', 'p[1091]', 1091)
# ('posterior', 'p[1092]', 1092)
# ('posterior', 'p[1093]', 1093)
# ('posterior', 'p[1094]', 1094)
# ('posterior', 'p[1095]', 1095)
# ('posterior', 'p[1096]', 1096)
# ('posterior', 'p[1097]', 1097)
# ('posterior', 'p[1098]', 1098)
# ('posterior', 'p[1099]', 1099)
# ('posterior', 'p[109]', 109)
# ('posterior', 'p[10]', 10)
# ('posterior', 'p[1100]', 1100)
# ('posterior', 'p[1101]', 1101)
# ('posterior', 'p[1102]', 1102)
# ('posterior', 'p[1103]', 1103)
# ('posterior', 'p[1104]', 1104)
# ('posterior', 'p[1105]', 1105)
# ('posterior', 'p[1106]', 1106)
# ('posterior', 'p[1107]', 1107)
# ('posterior', 'p[1108]', 1108)
# ('posterior', 'p[1109]', 1109)
# ('posterior', 'p[110]', 110)
# ('posterior', 'p[1110]', 1110)
# ('posterior', 'p[1111]', 1111)
# ('posterior', 'p[1112]', 1112)
# ('posterior', 'p[1113]', 1113)
# ('posterior', 'p[1114]', 1114)
# ('posterior', 'p[1115]', 1115)
# ('posterior', 'p[1116]', 1116)
# ('posterior', 'p[1117]', 1117)
# ('posterior', 'p[1118]', 1118)
# ('posterior', 'p[1119]', 1119)
# ('posterior', 'p[111]', 111)
# ('posterior', 'p[1120]', 1120)
# ('posterior', 'p[1121]', 1121)
# ('posterior', 'p[1122]', 1122)
# ('posterior', 'p[1123]', 1123)
# ('posterior', 'p[1124]', 1124)
# ('posterior', 'p[1125]', 1125)
# ('posterior', 'p[1126]', 1126)
# ('posterior', 'p[1127]', 1127)
# ('posterior', 'p[1128]', 1128)
# ('posterior', 'p[1129]', 1129)
# ('posterior', 'p[112]', 112)
# ('posterior', 'p[1130]', 1130)
# ('posterior', 'p[1131]', 1131)
# ('posterior', 'p[1132]', 1132)
# ('posterior', 'p[1133]', 1133)
# ('posterior', 'p[1134]', 1134)
# ('posterior', 'p[1135]', 1135)
# ('posterior', 'p[1136]', 1136)
# ('posterior', 'p[1137]', 1137)
# ('posterior', 'p[1138]', 1138)
# ('posterior', 'p[1139]', 1139)
# ('posterior', 'p[113]', 113)
# ('posterior', 'p[1140]', 1140)
# ('posterior', 'p[1141]', 1141)
# ('posterior', 'p[1142]', 1142)
# ('posterior', 'p[1143]', 1143)
# ('posterior', 'p[1144]', 1144)
# ('posterior', 'p[1145]', 1145)
# ('posterior', 'p[1146]', 1146)
# ('posterior', 'p[1147]', 1147)
# ('posterior', 'p[1148]', 1148)
# ('posterior', 'p[1149]', 1149)
# ('posterior', 'p[114]', 114)
# ('posterior', 'p[1150]', 1150)
# ('posterior', 'p[1151]', 1151)
# ('posterior', 'p[1152]', 1152)
# ('posterior', 'p[1153]', 1153)
# ('posterior', 'p[1154]', 1154)
# ('posterior', 'p[1155]', 1155)
# ('posterior', 'p[1156]', 1156)
# ('posterior', 'p[1157]', 1157)
# ('posterior', 'p[1158]', 1158)
# ('posterior', 'p[1159]', 1159)
# ('posterior', 'p[115]', 115)
# ('posterior', 'p[1160]', 1160)
# ('posterior', 'p[1161]', 1161)
# ('posterior', 'p[1162]', 1162)
# ('posterior', 'p[1163]', 1163)
# ('posterior', 'p[1164]', 1164)
# ('posterior', 'p[1165]', 1165)
# ('posterior', 'p[1166]', 1166)
# ('posterior', 'p[1167]', 1167)
# ('posterior', 'p[1168]', 1168)
# ('posterior', 'p[1169]', 1169)
# ('posterior', 'p[116]', 116)
# ('posterior', 'p[1170]', 1170)
# ('posterior', 'p[1171]', 1171)
# ('posterior', 'p[1172]', 1172)
# ('posterior', 'p[1173]', 1173)
# ('posterior', 'p[1174]', 1174)
# ('posterior', 'p[1175]', 1175)
# ('posterior', 'p[1176]', 1176)
# ('posterior', 'p[1177]', 1177)
# ('posterior', 'p[1178]', 1178)
# ('posterior', 'p[1179]', 1179)
# ('posterior', 'p[117]', 117)
# ('posterior', 'p[1180]', 1180)
# ('posterior', 'p[1181]', 1181)
# ('posterior', 'p[1182]', 1182)
# ('posterior', 'p[1183]', 1183)
# ('posterior', 'p[1184]', 1184)
# ('posterior', 'p[1185]', 1185)
# ('posterior', 'p[1186]', 1186)
# ('posterior', 'p[1187]', 1187)
# ('posterior', 'p[1188]', 1188)
# ('posterior', 'p[1189]', 1189)
# ('posterior', 'p[118]', 118)
# ('posterior', 'p[1190]', 1190)
# ('posterior', 'p[1191]', 1191)
# ('posterior', 'p[1192]', 1192)
# ('posterior', 'p[1193]', 1193)
# ('posterior', 'p[1194]', 1194)
# ('posterior', 'p[1195]', 1195)
# ('posterior', 'p[1196]', 1196)
# ('posterior', 'p[1197]', 1197)
# ('posterior', 'p[1198]', 1198)
# ('posterior', 'p[1199]', 1199)
# ('posterior', 'p[119]', 119)
# ('posterior', 'p[11]', 11)
# ('posterior', 'p[1200]', 1200)
# ('posterior', 'p[1201]', 1201)
# ('posterior', 'p[1202]', 1202)
# ('posterior', 'p[1203]', 1203)
# ('posterior', 'p[1204]', 1204)
# ('posterior', 'p[1205]', 1205)
# ('posterior', 'p[1206]', 1206)
# ('posterior', 'p[1207]', 1207)
# ('posterior', 'p[1208]', 1208)
# ('posterior', 'p[1209]', 1209)
# ('posterior', 'p[120]', 120)
# ('posterior', 'p[1210]', 1210)
# ('posterior', 'p[1211]', 1211)
# ('posterior', 'p[1212]', 1212)
# ('posterior', 'p[1213]', 1213)
# ('posterior', 'p[1214]', 1214)
# ('posterior', 'p[1215]', 1215)
# ('posterior', 'p[1216]', 1216)
# ('posterior', 'p[1217]', 1217)
# ('posterior', 'p[1218]', 1218)
# ('posterior', 'p[1219]', 1219)
# ('posterior', 'p[121]', 121)
# ('posterior', 'p[1220]', 1220)
# ('posterior', 'p[1221]', 1221)
# ('posterior', 'p[1222]', 1222)
# ('posterior', 'p[1223]', 1223)
# ('posterior', 'p[1224]', 1224)
# ('posterior', 'p[1225]', 1225)
# ('posterior', 'p[1226]', 1226)
# ('posterior', 'p[1227]', 1227)
# ('posterior', 'p[1228]', 1228)
# ('posterior', 'p[1229]', 1229)
# ('posterior', 'p[122]', 122)
# ('posterior', 'p[1230]', 1230)
# ('posterior', 'p[1231]', 1231)
# ('posterior', 'p[1232]', 1232)
# ('posterior', 'p[1233]', 1233)
# ('posterior', 'p[1234]', 1234)
# ('posterior', 'p[1235]', 1235)
# ('posterior', 'p[1236]', 1236)
# ('posterior', 'p[1237]', 1237)
# ('posterior', 'p[1238]', 1238)
# ('posterior', 'p[1239]', 1239)
# ('posterior', 'p[123]', 123)
# ('posterior', 'p[1240]', 1240)
# ('posterior', 'p[1241]', 1241)
# ('posterior', 'p[1242]', 1242)
# ('posterior', 'p[1243]', 1243)
# ('posterior', 'p[1244]', 1244)
# ('posterior', 'p[1245]', 1245)
# ('posterior', 'p[1246]', 1246)
# ('posterior', 'p[1247]', 1247)
# ('posterior', 'p[1248]', 1248)
# ('posterior', 'p[1249]', 1249)
# ('posterior', 'p[124]', 124)
# ('posterior', 'p[1250]', 1250)
# ('posterior', 'p[1251]', 1251)
# ('posterior', 'p[1252]', 1252)
# ('posterior', 'p[1253]', 1253)
# ('posterior', 'p[1254]', 1254)
# ('posterior', 'p[1255]', 1255)
# ('posterior', 'p[1256]', 1256)
# ('posterior', 'p[1257]', 1257)
# ('posterior', 'p[1258]', 1258)
# ('posterior', 'p[1259]', 1259)
# ('posterior', 'p[125]', 125)
# ('posterior', 'p[1260]', 1260)
# ('posterior', 'p[1261]', 1261)
# ('posterior', 'p[1262]', 1262)
# ('posterior', 'p[1263]', 1263)
# ('posterior', 'p[1264]', 1264)
# ('posterior', 'p[1265]', 1265)
# ('posterior', 'p[1266]', 1266)
# ('posterior', 'p[1267]', 1267)
# ('posterior', 'p[1268]', 1268)
# ('posterior', 'p[1269]', 1269)
# ('posterior', 'p[126]', 126)
# ('posterior', 'p[1270]', 1270)
# ('posterior', 'p[1271]', 1271)
# ('posterior', 'p[1272]', 1272)
# ('posterior', 'p[1273]', 1273)
# ('posterior', 'p[1274]', 1274)
# ('posterior', 'p[1275]', 1275)
# ('posterior', 'p[1276]', 1276)
# ('posterior', 'p[1277]', 1277)
# ('posterior', 'p[1278]', 1278)
# ('posterior', 'p[1279]', 1279)
# ('posterior', 'p[127]', 127)
# ('posterior', 'p[1280]', 1280)
# ('posterior', 'p[1281]', 1281)
# ('posterior', 'p[1282]', 1282)
# ('posterior', 'p[1283]', 1283)
# ('posterior', 'p[1284]', 1284)
# ('posterior', 'p[1285]', 1285)
# ('posterior', 'p[1286]', 1286)
# ('posterior', 'p[1287]', 1287)
# ('posterior', 'p[1288]', 1288)
# ('posterior', 'p[1289]', 1289)
# ('posterior', 'p[128]', 128)
# ('posterior', 'p[1290]', 1290)
# ('posterior', 'p[1291]', 1291)
# ('posterior', 'p[1292]', 1292)
# ('posterior', 'p[1293]', 1293)
# ('posterior', 'p[1294]', 1294)
# ('posterior', 'p[1295]', 1295)
# ('posterior', 'p[1296]', 1296)
# ('posterior', 'p[1297]', 1297)
# ('posterior', 'p[1298]', 1298)
# ('posterior', 'p[1299]', 1299)
# ('posterior', 'p[129]', 129)
# ('posterior', 'p[12]', 12)
# ('posterior', 'p[1300]', 1300)
# ('posterior', 'p[1301]', 1301)
# ('posterior', 'p[1302]', 1302)
# ('posterior', 'p[1303]', 1303)
# ('posterior', 'p[1304]', 1304)
# ('posterior', 'p[1305]', 1305)
# ('posterior', 'p[1306]', 1306)
# ('posterior', 'p[1307]', 1307)
# ('posterior', 'p[1308]', 1308)
# ('posterior', 'p[1309]', 1309)
# ('posterior', 'p[130]', 130)
# ('posterior', 'p[1310]', 1310)
# ('posterior', 'p[1311]', 1311)
# ('posterior', 'p[1312]', 1312)
# ('posterior', 'p[1313]', 1313)
# ('posterior', 'p[1314]', 1314)
# ('posterior', 'p[1315]', 1315)
# ('posterior', 'p[1316]', 1316)
# ('posterior', 'p[1317]', 1317)
# ('posterior', 'p[1318]', 1318)
# ('posterior', 'p[1319]', 1319)
# ('posterior', 'p[131]', 131)
# ('posterior', 'p[1320]', 1320)
# ('posterior', 'p[1321]', 1321)
# ('posterior', 'p[1322]', 1322)
# ('posterior', 'p[1323]', 1323)
# ('posterior', 'p[1324]', 1324)
# ('posterior', 'p[1325]', 1325)
# ('posterior', 'p[1326]', 1326)
# ('posterior', 'p[1327]', 1327)
# ('posterior', 'p[1328]', 1328)
# ('posterior', 'p[1329]', 1329)
# ('posterior', 'p[132]', 132)
# ('posterior', 'p[1330]', 1330)
# ('posterior', 'p[1331]', 1331)
# ('posterior', 'p[1332]', 1332)
# ('posterior', 'p[1333]', 1333)
# ('posterior', 'p[1334]', 1334)
# ('posterior', 'p[1335]', 1335)
# ('posterior', 'p[1336]', 1336)
# ('posterior', 'p[1337]', 1337)
# ('posterior', 'p[1338]', 1338)
# ('posterior', 'p[1339]', 1339)
# ('posterior', 'p[133]', 133)
# ('posterior', 'p[1340]', 1340)
# ('posterior', 'p[1341]', 1341)
# ('posterior', 'p[1342]', 1342)
# ('posterior', 'p[1343]', 1343)
# ('posterior', 'p[1344]', 1344)
# ('posterior', 'p[1345]', 1345)
# ('posterior', 'p[1346]', 1346)
# ('posterior', 'p[1347]', 1347)
# ('posterior', 'p[1348]', 1348)
# ('posterior', 'p[1349]', 1349)
# ('posterior', 'p[134]', 134)
# ('posterior', 'p[1350]', 1350)
# ('posterior', 'p[1351]', 1351)
# ('posterior', 'p[1352]', 1352)
# ('posterior', 'p[1353]', 1353)
# ('posterior', 'p[1354]', 1354)
# ('posterior', 'p[1355]', 1355)
# ('posterior', 'p[1356]', 1356)
# ('posterior', 'p[1357]', 1357)
# ('posterior', 'p[1358]', 1358)
# ('posterior', 'p[1359]', 1359)
# ('posterior', 'p[135]', 135)
# ('posterior', 'p[1360]', 1360)
# ('posterior', 'p[1361]', 1361)
# ('posterior', 'p[1362]', 1362)
# ('posterior', 'p[1363]', 1363)
# ('posterior', 'p[1364]', 1364)
# ('posterior', 'p[1365]', 1365)
# ('posterior', 'p[1366]', 1366)
# ('posterior', 'p[1367]', 1367)
# ('posterior', 'p[1368]', 1368)
# ('posterior', 'p[1369]', 1369)
# ('posterior', 'p[136]', 136)
# ('posterior', 'p[1370]', 1370)
# ('posterior', 'p[1371]', 1371)
# ('posterior', 'p[1372]', 1372)
# ('posterior', 'p[1373]', 1373)
# ('posterior', 'p[1374]', 1374)
# ('posterior', 'p[1375]', 1375)
# ('posterior', 'p[1376]', 1376)
# ('posterior', 'p[1377]', 1377)
# ('posterior', 'p[1378]', 1378)
# ('posterior', 'p[1379]', 1379)
# ('posterior', 'p[137]', 137)
# ('posterior', 'p[1380]', 1380)
# ('posterior', 'p[1381]', 1381)
# ('posterior', 'p[1382]', 1382)
# ('posterior', 'p[1383]', 1383)
# ('posterior', 'p[1384]', 1384)
# ('posterior', 'p[1385]', 1385)
# ('posterior', 'p[1386]', 1386)
# ('posterior', 'p[1387]', 1387)
# ('posterior', 'p[1388]', 1388)
# ('posterior', 'p[1389]', 1389)
# ('posterior', 'p[138]', 138)
# ('posterior', 'p[1390]', 1390)
# ('posterior', 'p[1391]', 1391)
# ('posterior', 'p[1392]', 1392)
# ('posterior', 'p[1393]', 1393)
# ('posterior', 'p[1394]', 1394)
# ('posterior', 'p[1395]', 1395)
# ('posterior', 'p[1396]', 1396)
# ('posterior', 'p[1397]', 1397)
# ('posterior', 'p[1398]', 1398)
# ('posterior', 'p[1399]', 1399)
# ('posterior', 'p[139]', 139)
# ('posterior', 'p[13]', 13)
# ('posterior', 'p[1400]', 1400)
# ('posterior', 'p[1401]', 1401)
# ('posterior', 'p[1402]', 1402)
# ('posterior', 'p[1403]', 1403)
# ('posterior', 'p[1404]', 1404)
# ('posterior', 'p[1405]', 1405)
# ('posterior', 'p[1406]', 1406)
# ('posterior', 'p[1407]', 1407)
# ('posterior', 'p[1408]', 1408)
# ('posterior', 'p[1409]', 1409)
# ('posterior', 'p[140]', 140)
# ('posterior', 'p[1410]', 1410)
# ('posterior', 'p[1411]', 1411)
# ('posterior', 'p[1412]', 1412)
# ('posterior', 'p[1413]', 1413)
# ('posterior', 'p[1414]', 1414)
# ('posterior', 'p[1415]', 1415)
# ('posterior', 'p[1416]', 1416)
# ('posterior', 'p[1417]', 1417)
# ('posterior', 'p[1418]', 1418)
# ('posterior', 'p[1419]', 1419)
# ('posterior', 'p[141]', 141)
# ('posterior', 'p[1420]', 1420)
# ('posterior', 'p[1421]', 1421)
# ('posterior', 'p[1422]', 1422)
# ('posterior', 'p[1423]', 1423)
# ('posterior', 'p[1424]', 1424)
# ('posterior', 'p[1425]', 1425)
# ('posterior', 'p[1426]', 1426)
# ('posterior', 'p[1427]', 1427)
# ('posterior', 'p[1428]', 1428)
# ('posterior', 'p[1429]', 1429)
# ('posterior', 'p[142]', 142)
# ('posterior', 'p[1430]', 1430)
# ('posterior', 'p[1431]', 1431)
# ('posterior', 'p[1432]', 1432)
# ('posterior', 'p[1433]', 1433)
# ('posterior', 'p[1434]', 1434)
# ('posterior', 'p[1435]', 1435)
# ('posterior', 'p[1436]', 1436)
# ('posterior', 'p[1437]', 1437)
# ('posterior', 'p[1438]', 1438)
# ('posterior', 'p[1439]', 1439)
# ('posterior', 'p[143]', 143)
# ('posterior', 'p[1440]', 1440)
# ('posterior', 'p[1441]', 1441)
# ('posterior', 'p[1442]', 1442)
# ('posterior', 'p[1443]', 1443)
# ('posterior', 'p[1444]', 1444)
# ('posterior', 'p[1445]', 1445)
# ('posterior', 'p[1446]', 1446)
# ('posterior', 'p[1447]', 1447)
# ('posterior', 'p[1448]', 1448)
# ('posterior', 'p[1449]', 1449)
# ('posterior', 'p[144]', 144)
# ('posterior', 'p[1450]', 1450)
# ('posterior', 'p[1451]', 1451)
# ('posterior', 'p[1452]', 1452)
# ('posterior', 'p[1453]', 1453)
# ('posterior', 'p[1454]', 1454)
# ('posterior', 'p[1455]', 1455)
# ('posterior', 'p[1456]', 1456)
# ('posterior', 'p[1457]', 1457)
# ('posterior', 'p[1458]', 1458)
# ('posterior', 'p[1459]', 1459)
# ('posterior', 'p[145]', 145)
# ('posterior', 'p[1460]', 1460)
# ('posterior', 'p[1461]', 1461)
# ('posterior', 'p[1462]', 1462)
# ('posterior', 'p[1463]', 1463)
# ('posterior', 'p[1464]', 1464)
# ('posterior', 'p[1465]', 1465)
# ('posterior', 'p[1466]', 1466)
# ('posterior', 'p[1467]', 1467)
# ('posterior', 'p[1468]', 1468)
# ('posterior', 'p[1469]', 1469)
# ('posterior', 'p[146]', 146)
# ('posterior', 'p[1470]', 1470)
# ('posterior', 'p[1471]', 1471)
# ('posterior', 'p[1472]', 1472)
# ('posterior', 'p[1473]', 1473)
# ('posterior', 'p[1474]', 1474)
# ('posterior', 'p[1475]', 1475)
# ('posterior', 'p[1476]', 1476)
# ('posterior', 'p[1477]', 1477)
# ('posterior', 'p[1478]', 1478)
# ('posterior', 'p[1479]', 1479)
# ('posterior', 'p[147]', 147)
# ('posterior', 'p[1480]', 1480)
# ('posterior', 'p[1481]', 1481)
# ('posterior', 'p[1482]', 1482)
# ('posterior', 'p[1483]', 1483)
# ('posterior', 'p[1484]', 1484)
# ('posterior', 'p[1485]', 1485)
# ('posterior', 'p[1486]', 1486)
# ('posterior', 'p[1487]', 1487)
# ('posterior', 'p[1488]', 1488)
# ('posterior', 'p[1489]', 1489)
# ('posterior', 'p[148]', 148)
# ('posterior', 'p[1490]', 1490)
# ('posterior', 'p[1491]', 1491)
# ('posterior', 'p[1492]', 1492)
# ('posterior', 'p[1493]', 1493)
# ('posterior', 'p[1494]', 1494)
# ('posterior', 'p[1495]', 1495)
# ('posterior', 'p[1496]', 1496)
# ('posterior', 'p[1497]', 1497)
# ('posterior', 'p[1498]', 1498)
# ('posterior', 'p[1499]', 1499)
# ('posterior', 'p[149]', 149)
# ('posterior', 'p[14]', 14)
# ('posterior', 'p[1500]', 1500)
# ('posterior', 'p[1501]', 1501)
# ('posterior', 'p[1502]', 1502)
# ('posterior', 'p[1503]', 1503)
# ('posterior', 'p[1504]', 1504)
# ('posterior', 'p[1505]', 1505)
# ('posterior', 'p[1506]', 1506)
# ('posterior', 'p[1507]', 1507)
# ('posterior', 'p[1508]', 1508)
# ('posterior', 'p[1509]', 1509)
# ('posterior', 'p[150]', 150)
# ('posterior', 'p[1510]', 1510)
# ('posterior', 'p[1511]', 1511)
# ('posterior', 'p[1512]', 1512)
# ('posterior', 'p[1513]', 1513)
# ('posterior', 'p[1514]', 1514)
# ('posterior', 'p[1515]', 1515)
# ('posterior', 'p[1516]', 1516)
# ('posterior', 'p[1517]', 1517)
# ('posterior', 'p[1518]', 1518)
# ('posterior', 'p[1519]', 1519)
# ('posterior', 'p[151]', 151)
# ('posterior', 'p[1520]', 1520)
# ('posterior', 'p[1521]', 1521)
# ('posterior', 'p[1522]', 1522)
# ('posterior', 'p[1523]', 1523)
# ('posterior', 'p[1524]', 1524)
# ('posterior', 'p[1525]', 1525)
# ('posterior', 'p[1526]', 1526)
# ('posterior', 'p[1527]', 1527)
# ('posterior', 'p[1528]', 1528)
# ('posterior', 'p[1529]', 1529)
# ('posterior', 'p[152]', 152)
# ('posterior', 'p[1530]', 1530)
# ('posterior', 'p[1531]', 1531)
# ('posterior', 'p[1532]', 1532)
# ('posterior', 'p[1533]', 1533)
# ('posterior', 'p[1534]', 1534)
# ('posterior', 'p[1535]', 1535)
# ('posterior', 'p[1536]', 1536)
# ('posterior', 'p[1537]', 1537)
# ('posterior', 'p[1538]', 1538)
# ('posterior', 'p[1539]', 1539)
# ('posterior', 'p[153]', 153)
# ('posterior', 'p[1540]', 1540)
# ('posterior', 'p[1541]', 1541)
# ('posterior', 'p[1542]', 1542)
# ('posterior', 'p[1543]', 1543)
# ('posterior', 'p[1544]', 1544)
# ('posterior', 'p[1545]', 1545)
# ('posterior', 'p[1546]', 1546)
# ('posterior', 'p[1547]', 1547)
# ('posterior', 'p[1548]', 1548)
# ('posterior', 'p[1549]', 1549)
# ('posterior', 'p[154]', 154)
# ('posterior', 'p[1550]', 1550)
# ('posterior', 'p[1551]', 1551)
# ('posterior', 'p[1552]', 1552)
# ('posterior', 'p[1553]', 1553)
# ('posterior', 'p[1554]', 1554)
# ('posterior', 'p[1555]', 1555)
# ('posterior', 'p[1556]', 1556)
# ('posterior', 'p[1557]', 1557)
# ('posterior', 'p[1558]', 1558)
# ('posterior', 'p[1559]', 1559)
# ('posterior', 'p[155]', 155)
# ('posterior', 'p[1560]', 1560)
# ('posterior', 'p[1561]', 1561)
# ('posterior', 'p[1562]', 1562)
# ('posterior', 'p[1563]', 1563)
# ('posterior', 'p[1564]', 1564)
# ('posterior', 'p[1565]', 1565)
# ('posterior', 'p[1566]', 1566)
# ('posterior', 'p[1567]', 1567)
# ('posterior', 'p[1568]', 1568)
# ('posterior', 'p[1569]', 1569)
# ('posterior', 'p[156]', 156)
# ('posterior', 'p[1570]', 1570)
# ('posterior', 'p[1571]', 1571)
# ('posterior', 'p[1572]', 1572)
# ('posterior', 'p[1573]', 1573)
# ('posterior', 'p[1574]', 1574)
# ('posterior', 'p[1575]', 1575)
# ('posterior', 'p[1576]', 1576)
# ('posterior', 'p[1577]', 1577)
# ('posterior', 'p[1578]', 1578)
# ('posterior', 'p[1579]', 1579)
# ('posterior', 'p[157]', 157)
# ('posterior', 'p[1580]', 1580)
# ('posterior', 'p[1581]', 1581)
# ('posterior', 'p[1582]', 1582)
# ('posterior', 'p[1583]', 1583)
# ('posterior', 'p[1584]', 1584)
# ('posterior', 'p[1585]', 1585)
# ('posterior', 'p[1586]', 1586)
# ('posterior', 'p[1587]', 1587)
# ('posterior', 'p[1588]', 1588)
# ('posterior', 'p[1589]', 1589)
# ('posterior', 'p[158]', 158)
# ('posterior', 'p[1590]', 1590)
# ('posterior', 'p[1591]', 1591)
# ('posterior', 'p[1592]', 1592)
# ('posterior', 'p[1593]', 1593)
# ('posterior', 'p[1594]', 1594)
# ('posterior', 'p[1595]', 1595)
# ('posterior', 'p[1596]', 1596)
# ('posterior', 'p[1597]', 1597)
# ('posterior', 'p[1598]', 1598)
# ('posterior', 'p[1599]', 1599)
# ('posterior', 'p[159]', 159)
# ('posterior', 'p[15]', 15)
# ('posterior', 'p[1600]', 1600)
# ('posterior', 'p[1601]', 1601)
# ('posterior', 'p[1602]', 1602)
# ('posterior', 'p[1603]', 1603)
# ('posterior', 'p[1604]', 1604)
# ('posterior', 'p[1605]', 1605)
# ('posterior', 'p[1606]', 1606)
# ('posterior', 'p[1607]', 1607)
# ('posterior', 'p[1608]', 1608)
# ('posterior', 'p[1609]', 1609)
# ('posterior', 'p[160]', 160)
# ('posterior', 'p[1610]', 1610)
# ('posterior', 'p[1611]', 1611)
# ('posterior', 'p[1612]', 1612)
# ('posterior', 'p[1613]', 1613)
# ('posterior', 'p[1614]', 1614)
# ('posterior', 'p[1615]', 1615)
# ('posterior', 'p[1616]', 1616)
# ('posterior', 'p[1617]', 1617)
# ('posterior', 'p[1618]', 1618)
# ('posterior', 'p[1619]', 1619)
# ('posterior', 'p[161]', 161)
# ('posterior', 'p[1620]', 1620)
# ('posterior', 'p[1621]', 1621)
# ('posterior', 'p[1622]', 1622)
# ('posterior', 'p[1623]', 1623)
# ('posterior', 'p[1624]', 1624)
# ('posterior', 'p[1625]', 1625)
# ('posterior', 'p[1626]', 1626)
# ('posterior', 'p[1627]', 1627)
# ('posterior', 'p[1628]', 1628)
# ('posterior', 'p[1629]', 1629)
# ('posterior', 'p[162]', 162)
# ('posterior', 'p[1630]', 1630)
# ('posterior', 'p[1631]', 1631)
# ('posterior', 'p[1632]', 1632)
# ('posterior', 'p[1633]', 1633)
# ('posterior', 'p[1634]', 1634)
# ('posterior', 'p[1635]', 1635)
# ('posterior', 'p[1636]', 1636)
# ('posterior', 'p[1637]', 1637)
# ('posterior', 'p[1638]', 1638)
# ('posterior', 'p[1639]', 1639)
# ('posterior', 'p[163]', 163)
# ('posterior', 'p[1640]', 1640)
# ('posterior', 'p[1641]', 1641)
# ('posterior', 'p[1642]', 1642)
# ('posterior', 'p[1643]', 1643)
# ('posterior', 'p[1644]', 1644)
# ('posterior', 'p[1645]', 1645)
# ('posterior', 'p[1646]', 1646)
# ('posterior', 'p[1647]', 1647)
# ('posterior', 'p[1648]', 1648)
# ('posterior', 'p[1649]', 1649)
# ('posterior', 'p[164]', 164)
# ('posterior', 'p[1650]', 1650)
# ('posterior', 'p[1651]', 1651)
# ('posterior', 'p[1652]', 1652)
# ('posterior', 'p[1653]', 1653)
# ('posterior', 'p[1654]', 1654)
# ('posterior', 'p[1655]', 1655)
# ('posterior', 'p[1656]', 1656)
# ('posterior', 'p[1657]', 1657)
# ('posterior', 'p[1658]', 1658)
# ('posterior', 'p[1659]', 1659)
# ('posterior', 'p[165]', 165)
# ('posterior', 'p[1660]', 1660)
# ('posterior', 'p[1661]', 1661)
# ('posterior', 'p[1662]', 1662)
# ('posterior', 'p[1663]', 1663)
# ('posterior', 'p[1664]', 1664)
# ('posterior', 'p[1665]', 1665)
# ('posterior', 'p[1666]', 1666)
# ('posterior', 'p[1667]', 1667)
# ('posterior', 'p[1668]', 1668)
# ('posterior', 'p[1669]', 1669)
# ('posterior', 'p[166]', 166)
# ('posterior', 'p[1670]', 1670)
# ('posterior', 'p[1671]', 1671)
# ('posterior', 'p[1672]', 1672)
# ('posterior', 'p[1673]', 1673)
# ('posterior', 'p[1674]', 1674)
# ('posterior', 'p[1675]', 1675)
# ('posterior', 'p[1676]', 1676)
# ('posterior', 'p[1677]', 1677)
# ('posterior', 'p[1678]', 1678)
# ('posterior', 'p[1679]', 1679)
# ('posterior', 'p[167]', 167)
# ('posterior', 'p[1680]', 1680)
# ('posterior', 'p[1681]', 1681)
# ('posterior', 'p[1682]', 1682)
# ('posterior', 'p[1683]', 1683)
# ('posterior', 'p[1684]', 1684)
# ('posterior', 'p[1685]', 1685)
# ('posterior', 'p[1686]', 1686)
# ('posterior', 'p[1687]', 1687)
# ('posterior', 'p[1688]', 1688)
# ('posterior', 'p[1689]', 1689)
# ('posterior', 'p[168]', 168)
# ('posterior', 'p[1690]', 1690)
# ('posterior', 'p[1691]', 1691)
# ('posterior', 'p[1692]', 1692)
# ('posterior', 'p[1693]', 1693)
# ('posterior', 'p[1694]', 1694)
# ('posterior', 'p[1695]', 1695)
# ('posterior', 'p[1696]', 1696)
# ('posterior', 'p[1697]', 1697)
# ('posterior', 'p[1698]', 1698)
# ('posterior', 'p[1699]', 1699)
# ('posterior', 'p[169]', 169)
# ('posterior', 'p[16]', 16)
# ('posterior', 'p[1700]', 1700)
# ('posterior', 'p[1701]', 1701)
# ('posterior', 'p[1702]', 1702)
# ('posterior', 'p[1703]', 1703)
# ('posterior', 'p[1704]', 1704)
# ('posterior', 'p[1705]', 1705)
# ('posterior', 'p[1706]', 1706)
# ('posterior', 'p[1707]', 1707)
# ('posterior', 'p[1708]', 1708)
# ('posterior', 'p[1709]', 1709)
# ('posterior', 'p[170]', 170)
# ('posterior', 'p[1710]', 1710)
# ('posterior', 'p[1711]', 1711)
# ('posterior', 'p[1712]', 1712)
# ('posterior', 'p[1713]', 1713)
# ('posterior', 'p[1714]', 1714)
# ('posterior', 'p[1715]', 1715)
# ('posterior', 'p[1716]', 1716)
# ('posterior', 'p[1717]', 1717)
# ('posterior', 'p[1718]', 1718)
# ('posterior', 'p[1719]', 1719)
# ('posterior', 'p[171]', 171)
# ('posterior', 'p[1720]', 1720)
# ('posterior', 'p[1721]', 1721)
# ('posterior', 'p[1722]', 1722)
# ('posterior', 'p[1723]', 1723)
# ('posterior', 'p[1724]', 1724)
# ('posterior', 'p[1725]', 1725)
# ('posterior', 'p[1726]', 1726)
# ('posterior', 'p[1727]', 1727)
# ('posterior', 'p[1728]', 1728)
# ('posterior', 'p[1729]', 1729)
# ('posterior', 'p[172]', 172)
# ('posterior', 'p[1730]', 1730)
# ('posterior', 'p[1731]', 1731)
# ('posterior', 'p[1732]', 1732)
# ('posterior', 'p[1733]', 1733)
# ('posterior', 'p[1734]', 1734)
# ('posterior', 'p[1735]', 1735)
# ('posterior', 'p[1736]', 1736)
# ('posterior', 'p[1737]', 1737)
# ('posterior', 'p[1738]', 1738)
# ('posterior', 'p[1739]', 1739)
# ('posterior', 'p[173]', 173)
# ('posterior', 'p[1740]', 1740)
# ('posterior', 'p[1741]', 1741)
# ('posterior', 'p[1742]', 1742)
# ('posterior', 'p[1743]', 1743)
# ('posterior', 'p[1744]', 1744)
# ('posterior', 'p[1745]', 1745)
# ('posterior', 'p[1746]', 1746)
# ('posterior', 'p[1747]', 1747)
# ('posterior', 'p[1748]', 1748)
# ('posterior', 'p[1749]', 1749)
# ('posterior', 'p[174]', 174)
# ('posterior', 'p[1750]', 1750)
# ('posterior', 'p[1751]', 1751)
# ('posterior', 'p[1752]', 1752)
# ('posterior', 'p[1753]', 1753)
# ('posterior', 'p[1754]', 1754)
# ('posterior', 'p[1755]', 1755)
# ('posterior', 'p[1756]', 1756)
# ('posterior', 'p[1757]', 1757)
# ('posterior', 'p[1758]', 1758)
# ('posterior', 'p[1759]', 1759)
# ('posterior', 'p[175]', 175)
# ('posterior', 'p[1760]', 1760)
# ('posterior', 'p[1761]', 1761)
# ('posterior', 'p[1762]', 1762)
# ('posterior', 'p[1763]', 1763)
# ('posterior', 'p[1764]', 1764)
# ('posterior', 'p[1765]', 1765)
# ('posterior', 'p[1766]', 1766)
# ('posterior', 'p[1767]', 1767)
# ('posterior', 'p[1768]', 1768)
# ('posterior', 'p[1769]', 1769)
# ('posterior', 'p[176]', 176)
# ('posterior', 'p[1770]', 1770)
# ('posterior', 'p[1771]', 1771)
# ('posterior', 'p[1772]', 1772)
# ('posterior', 'p[1773]', 1773)
# ('posterior', 'p[1774]', 1774)
# ('posterior', 'p[1775]', 1775)
# ('posterior', 'p[1776]', 1776)
# ('posterior', 'p[1777]', 1777)
# ('posterior', 'p[1778]', 1778)
# ('posterior', 'p[1779]', 1779)
# ('posterior', 'p[177]', 177)
# ('posterior', 'p[1780]', 1780)
# ('posterior', 'p[1781]', 1781)
# ('posterior', 'p[1782]', 1782)
# ('posterior', 'p[1783]', 1783)
# ('posterior', 'p[1784]', 1784)
# ('posterior', 'p[1785]', 1785)
# ('posterior', 'p[1786]', 1786)
# ('posterior', 'p[1787]', 1787)
# ('posterior', 'p[1788]', 1788)
# ('posterior', 'p[1789]', 1789)
# ('posterior', 'p[178]', 178)
# ('posterior', 'p[1790]', 1790)
# ('posterior', 'p[1791]', 1791)
# ('posterior', 'p[1792]', 1792)
# ('posterior', 'p[1793]', 1793)
# ('posterior', 'p[1794]', 1794)
# ('posterior', 'p[1795]', 1795)
# ('posterior', 'p[1796]', 1796)
# ('posterior', 'p[1797]', 1797)
# ('posterior', 'p[1798]', 1798)
# ('posterior', 'p[1799]', 1799)
# ('posterior', 'p[179]', 179)
# ('posterior', 'p[17]', 17)
# ('posterior', 'p[1800]', 1800)
# ('posterior', 'p[1801]', 1801)
# ('posterior', 'p[1802]', 1802)
# ('posterior', 'p[1803]', 1803)
# ('posterior', 'p[1804]', 1804)
# ('posterior', 'p[1805]', 1805)
# ('posterior', 'p[1806]', 1806)
# ('posterior', 'p[1807]', 1807)
# ('posterior', 'p[1808]', 1808)
# ('posterior', 'p[1809]', 1809)
# ('posterior', 'p[180]', 180)
# ('posterior', 'p[1810]', 1810)
# ('posterior', 'p[1811]', 1811)
# ('posterior', 'p[1812]', 1812)
# ('posterior', 'p[1813]', 1813)
# ('posterior', 'p[1814]', 1814)
# ('posterior', 'p[1815]', 1815)
# ('posterior', 'p[1816]', 1816)
# ('posterior', 'p[1817]', 1817)
# ('posterior', 'p[1818]', 1818)
# ('posterior', 'p[1819]', 1819)
# ('posterior', 'p[181]', 181)
# ('posterior', 'p[1820]', 1820)
# ('posterior', 'p[1821]', 1821)
# ('posterior', 'p[1822]', 1822)
# ('posterior', 'p[1823]', 1823)
# ('posterior', 'p[1824]', 1824)
# ('posterior', 'p[1825]', 1825)
# ('posterior', 'p[1826]', 1826)
# ('posterior', 'p[1827]', 1827)
# ('posterior', 'p[1828]', 1828)
# ('posterior', 'p[1829]', 1829)
# ('posterior', 'p[182]', 182)
# ('posterior', 'p[1830]', 1830)
# ('posterior', 'p[1831]', 1831)
# ('posterior', 'p[1832]', 1832)
# ('posterior', 'p[1833]', 1833)
# ('posterior', 'p[1834]', 1834)
# ('posterior', 'p[1835]', 1835)
# ('posterior', 'p[1836]', 1836)
# ('posterior', 'p[1837]', 1837)
# ('posterior', 'p[1838]', 1838)
# ('posterior', 'p[1839]', 1839)
# ('posterior', 'p[183]', 183)
# ('posterior', 'p[1840]', 1840)
# ('posterior', 'p[1841]', 1841)
# ('posterior', 'p[1842]', 1842)
# ('posterior', 'p[1843]', 1843)
# ('posterior', 'p[1844]', 1844)
# ('posterior', 'p[1845]', 1845)
# ('posterior', 'p[1846]', 1846)
# ('posterior', 'p[1847]', 1847)
# ('posterior', 'p[1848]', 1848)
# ('posterior', 'p[1849]', 1849)
# ('posterior', 'p[184]', 184)
# ('posterior', 'p[1850]', 1850)
# ('posterior', 'p[1851]', 1851)
# ('posterior', 'p[1852]', 1852)
# ('posterior', 'p[1853]', 1853)
# ('posterior', 'p[1854]', 1854)
# ('posterior', 'p[1855]', 1855)
# ('posterior', 'p[1856]', 1856)
# ('posterior', 'p[1857]', 1857)
# ('posterior', 'p[1858]', 1858)
# ('posterior', 'p[1859]', 1859)
# ('posterior', 'p[185]', 185)
# ('posterior', 'p[1860]', 1860)
# ('posterior', 'p[1861]', 1861)
# ('posterior', 'p[1862]', 1862)
# ('posterior', 'p[1863]', 1863)
# ('posterior', 'p[1864]', 1864)
# ('posterior', 'p[1865]', 1865)
# ('posterior', 'p[1866]', 1866)
# ('posterior', 'p[1867]', 1867)
# ('posterior', 'p[1868]', 1868)
# ('posterior', 'p[1869]', 1869)
# ('posterior', 'p[186]', 186)
# ('posterior', 'p[1870]', 1870)
# ('posterior', 'p[1871]', 1871)
# ('posterior', 'p[1872]', 1872)
# ('posterior', 'p[1873]', 1873)
# ('posterior', 'p[1874]', 1874)
# ('posterior', 'p[1875]', 1875)
# ('posterior', 'p[1876]', 1876)
# ('posterior', 'p[1877]', 1877)
# ('posterior', 'p[1878]', 1878)
# ('posterior', 'p[1879]', 1879)
# ('posterior', 'p[187]', 187)
# ('posterior', 'p[1880]', 1880)
# ('posterior', 'p[1881]', 1881)
# ('posterior', 'p[1882]', 1882)
# ('posterior', 'p[1883]', 1883)
# ('posterior', 'p[1884]', 1884)
# ('posterior', 'p[1885]', 1885)
# ('posterior', 'p[1886]', 1886)
# ('posterior', 'p[1887]', 1887)
# ('posterior', 'p[1888]', 1888)
# ('posterior', 'p[1889]', 1889)
# ('posterior', 'p[188]', 188)
# ('posterior', 'p[1890]', 1890)
# ('posterior', 'p[1891]', 1891)
# ('posterior', 'p[1892]', 1892)
# ('posterior', 'p[1893]', 1893)
# ('posterior', 'p[1894]', 1894)
# ('posterior', 'p[1895]', 1895)
# ('posterior', 'p[1896]', 1896)
# ('posterior', 'p[1897]', 1897)
# ('posterior', 'p[1898]', 1898)
# ('posterior', 'p[1899]', 1899)
# ('posterior', 'p[189]', 189)
# ('posterior', 'p[18]', 18)
# ('posterior', 'p[1900]', 1900)
# ('posterior', 'p[1901]', 1901)
# ('posterior', 'p[1902]', 1902)
# ('posterior', 'p[1903]', 1903)
# ('posterior', 'p[1904]', 1904)
# ('posterior', 'p[1905]', 1905)
# ('posterior', 'p[1906]', 1906)
# ('posterior', 'p[1907]', 1907)
# ('posterior', 'p[1908]', 1908)
# ('posterior', 'p[1909]', 1909)
# ('posterior', 'p[190]', 190)
# ('posterior', 'p[1910]', 1910)
# ('posterior', 'p[1911]', 1911)
# ('posterior', 'p[1912]', 1912)
# ('posterior', 'p[1913]', 1913)
# ('posterior', 'p[1914]', 1914)
# ('posterior', 'p[1915]', 1915)
# ('posterior', 'p[1916]', 1916)
# ('posterior', 'p[1917]', 1917)
# ('posterior', 'p[1918]', 1918)
# ('posterior', 'p[1919]', 1919)
# ('posterior', 'p[191]', 191)
# ('posterior', 'p[1920]', 1920)
# ('posterior', 'p[1921]', 1921)
# ('posterior', 'p[1922]', 1922)
# ('posterior', 'p[1923]', 1923)
# ('posterior', 'p[1924]', 1924)
# ('posterior', 'p[1925]', 1925)
# ('posterior', 'p[1926]', 1926)
# ('posterior', 'p[1927]', 1927)
# ('posterior', 'p[1928]', 1928)
# ('posterior', 'p[1929]', 1929)
# ('posterior', 'p[192]', 192)
# ('posterior', 'p[1930]', 1930)
# ('posterior', 'p[1931]', 1931)
# ('posterior', 'p[1932]', 1932)
# ('posterior', 'p[1933]', 1933)
# ('posterior', 'p[193]', 193)
# ('posterior', 'p[194]', 194)
# ('posterior', 'p[195]', 195)
# ('posterior', 'p[196]', 196)
# ('posterior', 'p[197]', 197)
# ('posterior', 'p[198]', 198)
# ('posterior', 'p[199]', 199)
# ('posterior', 'p[19]', 19)
# ('posterior', 'p[1]', 1)
# ('posterior', 'p[200]', 200)
# ('posterior', 'p[201]', 201)
# ('posterior', 'p[202]', 202)
# ('posterior', 'p[203]', 203)
# ('posterior', 'p[204]', 204)
# ('posterior', 'p[205]', 205)
# ('posterior', 'p[206]', 206)
# ('posterior', 'p[207]', 207)
# ('posterior', 'p[208]', 208)
# ('posterior', 'p[209]', 209)
# ('posterior', 'p[20]', 20)
# ('posterior', 'p[210]', 210)
# ('posterior', 'p[211]', 211)
# ('posterior', 'p[212]', 212)
# ('posterior', 'p[213]', 213)
# ('posterior', 'p[214]', 214)
# ('posterior', 'p[215]', 215)
# ('posterior', 'p[216]', 216)
# ('posterior', 'p[217]', 217)
# ('posterior', 'p[218]', 218)
# ('posterior', 'p[219]', 219)
# ('posterior', 'p[21]', 21)
# ('posterior', 'p[220]', 220)
# ('posterior', 'p[221]', 221)
# ('posterior', 'p[222]', 222)
# ('posterior', 'p[223]', 223)
# ('posterior', 'p[224]', 224)
# ('posterior', 'p[225]', 225)
# ('posterior', 'p[226]', 226)
# ('posterior', 'p[227]', 227)
# ('posterior', 'p[228]', 228)
# ('posterior', 'p[229]', 229)
# ('posterior', 'p[22]', 22)
# ('posterior', 'p[230]', 230)
# ('posterior', 'p[231]', 231)
# ('posterior', 'p[232]', 232)
# ('posterior', 'p[233]', 233)
# ('posterior', 'p[234]', 234)
# ('posterior', 'p[235]', 235)
# ('posterior', 'p[236]', 236)
# ('posterior', 'p[237]', 237)
# ('posterior', 'p[238]', 238)
# ('posterior', 'p[239]', 239)
# ('posterior', 'p[23]', 23)
# ('posterior', 'p[240]', 240)
# ('posterior', 'p[241]', 241)
# ('posterior', 'p[242]', 242)
# ('posterior', 'p[243]', 243)
# ('posterior', 'p[244]', 244)
# ('posterior', 'p[245]', 245)
# ('posterior', 'p[246]', 246)
# ('posterior', 'p[247]', 247)
# ('posterior', 'p[248]', 248)
# ('posterior', 'p[249]', 249)
# ('posterior', 'p[24]', 24)
# ('posterior', 'p[250]', 250)
# ('posterior', 'p[251]', 251)
# ('posterior', 'p[252]', 252)
# ('posterior', 'p[253]', 253)
# ('posterior', 'p[254]', 254)
# ('posterior', 'p[255]', 255)
# ('posterior', 'p[256]', 256)
# ('posterior', 'p[257]', 257)
# ('posterior', 'p[258]', 258)
# ('posterior', 'p[259]', 259)
# ('posterior', 'p[25]', 25)
# ('posterior', 'p[260]', 260)
# ('posterior', 'p[261]', 261)
# ('posterior', 'p[262]', 262)
# ('posterior', 'p[263]', 263)
# ('posterior', 'p[264]', 264)
# ('posterior', 'p[265]', 265)
# ('posterior', 'p[266]', 266)
# ('posterior', 'p[267]', 267)
# ('posterior', 'p[268]', 268)
# ('posterior', 'p[269]', 269)
# ('posterior', 'p[26]', 26)
# ('posterior', 'p[270]', 270)
# ('posterior', 'p[271]', 271)
# ('posterior', 'p[272]', 272)
# ('posterior', 'p[273]', 273)
# ('posterior', 'p[274]', 274)
# ('posterior', 'p[275]', 275)
# ('posterior', 'p[276]', 276)
# ('posterior', 'p[277]', 277)
# ('posterior', 'p[278]', 278)
# ('posterior', 'p[279]', 279)
# ('posterior', 'p[27]', 27)
# ('posterior', 'p[280]', 280)
# ('posterior', 'p[281]', 281)
# ('posterior', 'p[282]', 282)
# ('posterior', 'p[283]', 283)
# ('posterior', 'p[284]', 284)
# ('posterior', 'p[285]', 285)
# ('posterior', 'p[286]', 286)
# ('posterior', 'p[287]', 287)
# ('posterior', 'p[288]', 288)
# ('posterior', 'p[289]', 289)
# ('posterior', 'p[28]', 28)
# ('posterior', 'p[290]', 290)
# ('posterior', 'p[291]', 291)
# ('posterior', 'p[292]', 292)
# ('posterior', 'p[293]', 293)
# ('posterior', 'p[294]', 294)
# ('posterior', 'p[295]', 295)
# ('posterior', 'p[296]', 296)
# ('posterior', 'p[297]', 297)
# ('posterior', 'p[298]', 298)
# ('posterior', 'p[299]', 299)
# ('posterior', 'p[29]', 29)
# ('posterior', 'p[2]', 2)
# ('posterior', 'p[300]', 300)
# ('posterior', 'p[301]', 301)
# ('posterior', 'p[302]', 302)
# ('posterior', 'p[303]', 303)
# ('posterior', 'p[304]', 304)
# ('posterior', 'p[305]', 305)
# ('posterior', 'p[306]', 306)
# ('posterior', 'p[307]', 307)
# ('posterior', 'p[308]', 308)
# ('posterior', 'p[309]', 309)
# ('posterior', 'p[30]', 30)
# ('posterior', 'p[310]', 310)
# ('posterior', 'p[311]', 311)
# ('posterior', 'p[312]', 312)
# ('posterior', 'p[313]', 313)
# ('posterior', 'p[314]', 314)
# ('posterior', 'p[315]', 315)
# ('posterior', 'p[316]', 316)
# ('posterior', 'p[317]', 317)
# ('posterior', 'p[318]', 318)
# ('posterior', 'p[319]', 319)
# ('posterior', 'p[31]', 31)
# ('posterior', 'p[320]', 320)
# ('posterior', 'p[321]', 321)
# ('posterior', 'p[322]', 322)
# ('posterior', 'p[323]', 323)
# ('posterior', 'p[324]', 324)
# ('posterior', 'p[325]', 325)
# ('posterior', 'p[326]', 326)
# ('posterior', 'p[327]', 327)
# ('posterior', 'p[328]', 328)
# ('posterior', 'p[329]', 329)
# ('posterior', 'p[32]', 32)
# ('posterior', 'p[330]', 330)
# ('posterior', 'p[331]', 331)
# ('posterior', 'p[332]', 332)
# ('posterior', 'p[333]', 333)
# ('posterior', 'p[334]', 334)
# ('posterior', 'p[335]', 335)
# ('posterior', 'p[336]', 336)
# ('posterior', 'p[337]', 337)
# ('posterior', 'p[338]', 338)
# ('posterior', 'p[339]', 339)
# ('posterior', 'p[33]', 33)
# ('posterior', 'p[340]', 340)
# ('posterior', 'p[341]', 341)
# ('posterior', 'p[342]', 342)
# ('posterior', 'p[343]', 343)
# ('posterior', 'p[344]', 344)
# ('posterior', 'p[345]', 345)
# ('posterior', 'p[346]', 346)
# ('posterior', 'p[347]', 347)
# ('posterior', 'p[348]', 348)
# ('posterior', 'p[349]', 349)
# ('posterior', 'p[34]', 34)
# ('posterior', 'p[350]', 350)
# ('posterior', 'p[351]', 351)
# ('posterior', 'p[352]', 352)
# ('posterior', 'p[353]', 353)
# ('posterior', 'p[354]', 354)
# ('posterior', 'p[355]', 355)
# ('posterior', 'p[356]', 356)
# ('posterior', 'p[357]', 357)
# ('posterior', 'p[358]', 358)
# ('posterior', 'p[359]', 359)
# ('posterior', 'p[35]', 35)
# ('posterior', 'p[360]', 360)
# ('posterior', 'p[361]', 361)
# ('posterior', 'p[362]', 362)
# ('posterior', 'p[363]', 363)
# ('posterior', 'p[364]', 364)
# ('posterior', 'p[365]', 365)
# ('posterior', 'p[366]', 366)
# ('posterior', 'p[367]', 367)
# ('posterior', 'p[368]', 368)
# ('posterior', 'p[369]', 369)
# ('posterior', 'p[36]', 36)
# ('posterior', 'p[370]', 370)
# ('posterior', 'p[371]', 371)
# ('posterior', 'p[372]', 372)
# ('posterior', 'p[373]', 373)
# ('posterior', 'p[374]', 374)
# ('posterior', 'p[375]', 375)
# ('posterior', 'p[376]', 376)
# ('posterior', 'p[377]', 377)
# ('posterior', 'p[378]', 378)
# ('posterior', 'p[379]', 379)
# ('posterior', 'p[37]', 37)
# ('posterior', 'p[380]', 380)
# ('posterior', 'p[381]', 381)
# ('posterior', 'p[382]', 382)
# ('posterior', 'p[383]', 383)
# ('posterior', 'p[384]', 384)
# ('posterior', 'p[385]', 385)
# ('posterior', 'p[386]', 386)
# ('posterior', 'p[387]', 387)
# ('posterior', 'p[388]', 388)
# ('posterior', 'p[389]', 389)
# ('posterior', 'p[38]', 38)
# ('posterior', 'p[390]', 390)
# ('posterior', 'p[391]', 391)
# ('posterior', 'p[392]', 392)
# ('posterior', 'p[393]', 393)
# ('posterior', 'p[394]', 394)
# ('posterior', 'p[395]', 395)
# ('posterior', 'p[396]', 396)
# ('posterior', 'p[397]', 397)
# ('posterior', 'p[398]', 398)
# ('posterior', 'p[399]', 399)
# ('posterior', 'p[39]', 39)
# ('posterior', 'p[3]', 3)
# ('posterior', 'p[400]', 400)
# ('posterior', 'p[401]', 401)
# ('posterior', 'p[402]', 402)
# ('posterior', 'p[403]', 403)
# ('posterior', 'p[404]', 404)
# ('posterior', 'p[405]', 405)
# ('posterior', 'p[406]', 406)
# ('posterior', 'p[407]', 407)
# ('posterior', 'p[408]', 408)
# ('posterior', 'p[409]', 409)
# ('posterior', 'p[40]', 40)
# ('posterior', 'p[410]', 410)
# ('posterior', 'p[411]', 411)
# ('posterior', 'p[412]', 412)
# ('posterior', 'p[413]', 413)
# ('posterior', 'p[414]', 414)
# ('posterior', 'p[415]', 415)
# ('posterior', 'p[416]', 416)
# ('posterior', 'p[417]', 417)
# ('posterior', 'p[418]', 418)
# ('posterior', 'p[419]', 419)
# ('posterior', 'p[41]', 41)
# ('posterior', 'p[420]', 420)
# ('posterior', 'p[421]', 421)
# ('posterior', 'p[422]', 422)
# ('posterior', 'p[423]', 423)
# ('posterior', 'p[424]', 424)
# ('posterior', 'p[425]', 425)
# ('posterior', 'p[426]', 426)
# ('posterior', 'p[427]', 427)
# ('posterior', 'p[428]', 428)
# ('posterior', 'p[429]', 429)
# ('posterior', 'p[42]', 42)
# ('posterior', 'p[430]', 430)
# ('posterior', 'p[431]', 431)
# ('posterior', 'p[432]', 432)
# ('posterior', 'p[433]', 433)
# ('posterior', 'p[434]', 434)
# ('posterior', 'p[435]', 435)
# ('posterior', 'p[436]', 436)
# ('posterior', 'p[437]', 437)
# ('posterior', 'p[438]', 438)
# ('posterior', 'p[439]', 439)
# ('posterior', 'p[43]', 43)
# ('posterior', 'p[440]', 440)
# ('posterior', 'p[441]', 441)
# ('posterior', 'p[442]', 442)
# ('posterior', 'p[443]', 443)
# ('posterior', 'p[444]', 444)
# ('posterior', 'p[445]', 445)
# ('posterior', 'p[446]', 446)
# ('posterior', 'p[447]', 447)
# ('posterior', 'p[448]', 448)
# ('posterior', 'p[449]', 449)
# ('posterior', 'p[44]', 44)
# ('posterior', 'p[450]', 450)
# ('posterior', 'p[451]', 451)
# ('posterior', 'p[452]', 452)
# ('posterior', 'p[453]', 453)
# ('posterior', 'p[454]', 454)
# ('posterior', 'p[455]', 455)
# ('posterior', 'p[456]', 456)
# ('posterior', 'p[457]', 457)
# ('posterior', 'p[458]', 458)
# ('posterior', 'p[459]', 459)
# ('posterior', 'p[45]', 45)
# ('posterior', 'p[460]', 460)
# ('posterior', 'p[461]', 461)
# ('posterior', 'p[462]', 462)
# ('posterior', 'p[463]', 463)
# ('posterior', 'p[464]', 464)
# ('posterior', 'p[465]', 465)
# ('posterior', 'p[466]', 466)
# ('posterior', 'p[467]', 467)
# ('posterior', 'p[468]', 468)
# ('posterior', 'p[469]', 469)
# ('posterior', 'p[46]', 46)
# ('posterior', 'p[470]', 470)
# ('posterior', 'p[471]', 471)
# ('posterior', 'p[472]', 472)
# ('posterior', 'p[473]', 473)
# ('posterior', 'p[474]', 474)
# ('posterior', 'p[475]', 475)
# ('posterior', 'p[476]', 476)
# ('posterior', 'p[477]', 477)
# ('posterior', 'p[478]', 478)
# ('posterior', 'p[479]', 479)
# ('posterior', 'p[47]', 47)
# ('posterior', 'p[480]', 480)
# ('posterior', 'p[481]', 481)
# ('posterior', 'p[482]', 482)
# ('posterior', 'p[483]', 483)
# ('posterior', 'p[484]', 484)
# ('posterior', 'p[485]', 485)
# ('posterior', 'p[486]', 486)
# ('posterior', 'p[487]', 487)
# ('posterior', 'p[488]', 488)
# ('posterior', 'p[489]', 489)
# ('posterior', 'p[48]', 48)
# ('posterior', 'p[490]', 490)
# ('posterior', 'p[491]', 491)
# ('posterior', 'p[492]', 492)
# ('posterior', 'p[493]', 493)
# ('posterior', 'p[494]', 494)
# ('posterior', 'p[495]', 495)
# ('posterior', 'p[496]', 496)
# ('posterior', 'p[497]', 497)
# ('posterior', 'p[498]', 498)
# ('posterior', 'p[499]', 499)
# ('posterior', 'p[49]', 49)
# ('posterior', 'p[4]', 4)
# ('posterior', 'p[500]', 500)
# ('posterior', 'p[501]', 501)
# ('posterior', 'p[502]', 502)
# ('posterior', 'p[503]', 503)
# ('posterior', 'p[504]', 504)
# ('posterior', 'p[505]', 505)
# ('posterior', 'p[506]', 506)
# ('posterior', 'p[507]', 507)
# ('posterior', 'p[508]', 508)
# ('posterior', 'p[509]', 509)
# ('posterior', 'p[50]', 50)
# ('posterior', 'p[510]', 510)
# ('posterior', 'p[511]', 511)
# ('posterior', 'p[512]', 512)
# ('posterior', 'p[513]', 513)
# ('posterior', 'p[514]', 514)
# ('posterior', 'p[515]', 515)
# ('posterior', 'p[516]', 516)
# ('posterior', 'p[517]', 517)
# ('posterior', 'p[518]', 518)
# ('posterior', 'p[519]', 519)
# ('posterior', 'p[51]', 51)
# ('posterior', 'p[520]', 520)
# ('posterior', 'p[521]', 521)
# ('posterior', 'p[522]', 522)
# ('posterior', 'p[523]', 523)
# ('posterior', 'p[524]', 524)
# ('posterior', 'p[525]', 525)
# ('posterior', 'p[526]', 526)
# ...
# ('log_likelihood', 'c[773]', 773)
# ('log_likelihood', 'c[774]', 774)
# ('log_likelihood', 'c[775]', 775)
# ('log_likelihood', 'c[776]', 776)
# ('log_likelihood', 'c[777]', 777)
# ('log_likelihood', 'c[778]', 778)
# ('log_likelihood', 'c[779]', 779)
# ('log_likelihood', 'c[77]', 77)
# ('log_likelihood', 'c[780]', 780)
# ('log_likelihood', 'c[781]', 781)
# ('log_likelihood', 'c[782]', 782)
# ('log_likelihood', 'c[783]', 783)
# ('log_likelihood', 'c[784]', 784)
# ('log_likelihood', 'c[785]', 785)
# ('log_likelihood', 'c[786]', 786)
# ('log_likelihood', 'c[787]', 787)
# ('log_likelihood', 'c[788]', 788)
# ('log_likelihood', 'c[789]', 789)
# ('log_likelihood', 'c[78]', 78)
# ('log_likelihood', 'c[790]', 790)
# ('log_likelihood', 'c[791]', 791)
# ('log_likelihood', 'c[792]', 792)
# ('log_likelihood', 'c[793]', 793)
# ('log_likelihood', 'c[794]', 794)
# ('log_likelihood', 'c[795]', 795)
# ('log_likelihood', 'c[796]', 796)
# ('log_likelihood', 'c[797]', 797)
# ('log_likelihood', 'c[798]', 798)
# ('log_likelihood', 'c[799]', 799)
# ('log_likelihood', 'c[79]', 79)
# ('log_likelihood', 'c[7]', 7)
# ('log_likelihood', 'c[800]', 800)
# ('log_likelihood', 'c[801]', 801)
# ('log_likelihood', 'c[802]', 802)
# ('log_likelihood', 'c[803]', 803)
# ('log_likelihood', 'c[804]', 804)
# ('log_likelihood', 'c[805]', 805)
# ('log_likelihood', 'c[806]', 806)
# ('log_likelihood', 'c[807]', 807)
# ('log_likelihood', 'c[808]', 808)
# ('log_likelihood', 'c[809]', 809)
# ('log_likelihood', 'c[80]', 80)
# ('log_likelihood', 'c[810]', 810)
# ('log_likelihood', 'c[811]', 811)
# ('log_likelihood', 'c[812]', 812)
# ('log_likelihood', 'c[813]', 813)
# ('log_likelihood', 'c[814]', 814)
# ('log_likelihood', 'c[815]', 815)
# ('log_likelihood', 'c[816]', 816)
# ('log_likelihood', 'c[817]', 817)
# ('log_likelihood', 'c[818]', 818)
# ('log_likelihood', 'c[819]', 819)
# ('log_likelihood', 'c[81]', 81)
# ('log_likelihood', 'c[820]', 820)
# ('log_likelihood', 'c[821]', 821)
# ('log_likelihood', 'c[822]', 822)
# ('log_likelihood', 'c[823]', 823)
# ('log_likelihood', 'c[824]', 824)
# ('log_likelihood', 'c[825]', 825)
# ('log_likelihood', 'c[826]', 826)
# ('log_likelihood', 'c[827]', 827)
# ('log_likelihood', 'c[828]', 828)
# ('log_likelihood', 'c[829]', 829)
# ('log_likelihood', 'c[82]', 82)
# ('log_likelihood', 'c[830]', 830)
# ('log_likelihood', 'c[831]', 831)
# ('log_likelihood', 'c[832]', 832)
# ('log_likelihood', 'c[833]', 833)
# ('log_likelihood', 'c[834]', 834)
# ('log_likelihood', 'c[835]', 835)
# ('log_likelihood', 'c[836]', 836)
# ('log_likelihood', 'c[837]', 837)
# ('log_likelihood', 'c[838]', 838)
# ('log_likelihood', 'c[839]', 839)
# ('log_likelihood', 'c[83]', 83)
# ('log_likelihood', 'c[840]', 840)
# ('log_likelihood', 'c[841]', 841)
# ('log_likelihood', 'c[842]', 842)
# ('log_likelihood', 'c[843]', 843)
# ('log_likelihood', 'c[844]', 844)
# ('log_likelihood', 'c[845]', 845)
# ('log_likelihood', 'c[846]', 846)
# ('log_likelihood', 'c[847]', 847)
# ('log_likelihood', 'c[848]', 848)
# ('log_likelihood', 'c[849]', 849)
# ('log_likelihood', 'c[84]', 84)
# ('log_likelihood', 'c[850]', 850)
# ('log_likelihood', 'c[851]', 851)
# ('log_likelihood', 'c[852]', 852)
# ('log_likelihood', 'c[853]', 853)
# ('log_likelihood', 'c[854]', 854)
# ('log_likelihood', 'c[855]', 855)
# ('log_likelihood', 'c[856]', 856)
# ('log_likelihood', 'c[857]', 857)
# ('log_likelihood', 'c[858]', 858)
# ('log_likelihood', 'c[859]', 859)
# ('log_likelihood', 'c[85]', 85)
# ('log_likelihood', 'c[860]', 860)
# ('log_likelihood', 'c[861]', 861)
# ('log_likelihood', 'c[862]', 862)
# ('log_likelihood', 'c[863]', 863)
# ('log_likelihood', 'c[864]', 864)
# ('log_likelihood', 'c[865]', 865)
# ('log_likelihood', 'c[866]', 866)
# ('log_likelihood', 'c[867]', 867)
# ('log_likelihood', 'c[868]', 868)
# ('log_likelihood', 'c[869]', 869)
# ('log_likelihood', 'c[86]', 86)
# ('log_likelihood', 'c[870]', 870)
# ('log_likelihood', 'c[871]', 871)
# ('log_likelihood', 'c[872]', 872)
# ('log_likelihood', 'c[873]', 873)
# ('log_likelihood', 'c[874]', 874)
# ('log_likelihood', 'c[875]', 875)
# ('log_likelihood', 'c[876]', 876)
# ('log_likelihood', 'c[877]', 877)
# ('log_likelihood', 'c[878]', 878)
# ('log_likelihood', 'c[879]', 879)
# ('log_likelihood', 'c[87]', 87)
# ('log_likelihood', 'c[880]', 880)
# ('log_likelihood', 'c[881]', 881)
# ('log_likelihood', 'c[882]', 882)
# ('log_likelihood', 'c[883]', 883)
# ('log_likelihood', 'c[884]', 884)
# ('log_likelihood', 'c[885]', 885)
# ('log_likelihood', 'c[886]', 886)
# ('log_likelihood', 'c[887]', 887)
# ('log_likelihood', 'c[888]', 888)
# ('log_likelihood', 'c[889]', 889)
# ('log_likelihood', 'c[88]', 88)
# ('log_likelihood', 'c[890]', 890)
# ('log_likelihood', 'c[891]', 891)
# ('log_likelihood', 'c[892]', 892)
# ('log_likelihood', 'c[893]', 893)
# ('log_likelihood', 'c[894]', 894)
# ('log_likelihood', 'c[895]', 895)
# ('log_likelihood', 'c[896]', 896)
# ('log_likelihood', 'c[897]', 897)
# ('log_likelihood', 'c[898]', 898)
# ('log_likelihood', 'c[899]', 899)
# ('log_likelihood', 'c[89]', 89)
# ('log_likelihood', 'c[8]', 8)
# ('log_likelihood', 'c[900]', 900)
# ('log_likelihood', 'c[901]', 901)
# ('log_likelihood', 'c[902]', 902)
# ('log_likelihood', 'c[903]', 903)
# ('log_likelihood', 'c[904]', 904)
# ('log_likelihood', 'c[905]', 905)
# ('log_likelihood', 'c[906]', 906)
# ('log_likelihood', 'c[907]', 907)
# ('log_likelihood', 'c[908]', 908)
# ('log_likelihood', 'c[909]', 909)
# ('log_likelihood', 'c[90]', 90)
# ('log_likelihood', 'c[910]', 910)
# ('log_likelihood', 'c[911]', 911)
# ('log_likelihood', 'c[912]', 912)
# ('log_likelihood', 'c[913]', 913)
# ('log_likelihood', 'c[914]', 914)
# ('log_likelihood', 'c[915]', 915)
# ('log_likelihood', 'c[916]', 916)
# ('log_likelihood', 'c[917]', 917)
# ('log_likelihood', 'c[918]', 918)
# ('log_likelihood', 'c[919]', 919)
# ('log_likelihood', 'c[91]', 91)
# ('log_likelihood', 'c[920]', 920)
# ('log_likelihood', 'c[921]', 921)
# ('log_likelihood', 'c[922]', 922)
# ('log_likelihood', 'c[923]', 923)
# ('log_likelihood', 'c[924]', 924)
# ('log_likelihood', 'c[925]', 925)
# ('log_likelihood', 'c[926]', 926)
# ('log_likelihood', 'c[927]', 927)
# ('log_likelihood', 'c[928]', 928)
# ('log_likelihood', 'c[929]', 929)
# ('log_likelihood', 'c[92]', 92)
# ('log_likelihood', 'c[930]', 930)
# ('log_likelihood', 'c[931]', 931)
# ('log_likelihood', 'c[932]', 932)
# ('log_likelihood', 'c[933]', 933)
# ('log_likelihood', 'c[934]', 934)
# ('log_likelihood', 'c[935]', 935)
# ('log_likelihood', 'c[936]', 936)
# ('log_likelihood', 'c[937]', 937)
# ('log_likelihood', 'c[938]', 938)
# ('log_likelihood', 'c[939]', 939)
# ('log_likelihood', 'c[93]', 93)
# ('log_likelihood', 'c[940]', 940)
# ('log_likelihood', 'c[941]', 941)
# ('log_likelihood', 'c[942]', 942)
# ('log_likelihood', 'c[943]', 943)
# ('log_likelihood', 'c[944]', 944)
# ('log_likelihood', 'c[945]', 945)
# ('log_likelihood', 'c[946]', 946)
# ('log_likelihood', 'c[947]', 947)
# ('log_likelihood', 'c[948]', 948)
# ('log_likelihood', 'c[949]', 949)
# ('log_likelihood', 'c[94]', 94)
# ('log_likelihood', 'c[950]', 950)
# ('log_likelihood', 'c[951]', 951)
# ('log_likelihood', 'c[952]', 952)
# ('log_likelihood', 'c[953]', 953)
# ('log_likelihood', 'c[954]', 954)
# ('log_likelihood', 'c[955]', 955)
# ('log_likelihood', 'c[956]', 956)
# ('log_likelihood', 'c[957]', 957)
# ('log_likelihood', 'c[958]', 958)
# ('log_likelihood', 'c[959]', 959)
# ('log_likelihood', 'c[95]', 95)
# ('log_likelihood', 'c[960]', 960)
# ('log_likelihood', 'c[961]', 961)
# ('log_likelihood', 'c[962]', 962)
# ('log_likelihood', 'c[963]', 963)
# ('log_likelihood', 'c[964]', 964)
# ('log_likelihood', 'c[965]', 965)
# ('log_likelihood', 'c[966]', 966)
# ('log_likelihood', 'c[967]', 967)
# ('log_likelihood', 'c[968]', 968)
# ('log_likelihood', 'c[969]', 969)
# ('log_likelihood', 'c[96]', 96)
# ('log_likelihood', 'c[970]', 970)
# ('log_likelihood', 'c[971]', 971)
# ('log_likelihood', 'c[972]', 972)
# ('log_likelihood', 'c[973]', 973)
# ('log_likelihood', 'c[974]', 974)
# ('log_likelihood', 'c[975]', 975)
# ('log_likelihood', 'c[976]', 976)
# ('log_likelihood', 'c[977]', 977)
# ('log_likelihood', 'c[978]', 978)
# ('log_likelihood', 'c[979]', 979)
# ('log_likelihood', 'c[97]', 97)
# ('log_likelihood', 'c[980]', 980)
# ('log_likelihood', 'c[981]', 981)
# ('log_likelihood', 'c[982]', 982)
# ('log_likelihood', 'c[983]', 983)
# ('log_likelihood', 'c[984]', 984)
# ('log_likelihood', 'c[985]', 985)
# ('log_likelihood', 'c[986]', 986)
# ('log_likelihood', 'c[987]', 987)
# ('log_likelihood', 'c[988]', 988)
# ('log_likelihood', 'c[989]', 989)
# ('log_likelihood', 'c[98]', 98)
# ('log_likelihood', 'c[990]', 990)
# ('log_likelihood', 'c[991]', 991)
# ('log_likelihood', 'c[992]', 992)
# ('log_likelihood', 'c[993]', 993)
# ('log_likelihood', 'c[994]', 994)
# ('log_likelihood', 'c[995]', 995)
# ('log_likelihood', 'c[996]', 996)
# ('log_likelihood', 'c[997]', 997)
# ('log_likelihood', 'c[998]', 998)
# ('log_likelihood', 'c[999]', 999)
# ('log_likelihood', 'c[99]', 99)
# ('log_likelihood', 'c[9]', 9)
# ('sample_stats', 'tree_size')
# ('sample_stats', 'process_time_diff')
# ('sample_stats', 'step_size')
# ('sample_stats', 'step_size_bar')
# ('sample_stats', 'depth')
# ('sample_stats', 'mean_tree_accept')
# ('sample_stats', 'energy_error')
# ('sample_stats', 'max_energy_error')
# ('sample_stats', 'energy')
# ('sample_stats', 'lp')
# ('sample_stats', 'diverging')
# ('sample_stats', 'perf_counter_start')
# ('sample_stats', 'perf_counter_diff')
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
# Get posterior of the rho value
trace_mvse_df[("posterior", "chol_cov_corr[0,1]", 0, 1)]
# Out:
# 0      -0.781319
# 1      -0.863538
# 2      -0.531439
# 3      -0.581260
# 4      -0.581571
#           ...
# 3995   -0.802648
# 3996   -0.828686
# 3997   -0.810492
# 3998   -0.821354
# 3999   -0.818089
# Name: (posterior, chol_cov_corr[0,1], 0, 1), Length: 4000, dtype: float64

# %%
# Code informed/modified from repo
f, ax1 = plt.subplots()

# prior
R = pm.LKJCorr.dist(n=2, eta=2).random(size=10000)
az.plot_kde(R, plot_kwargs={"color": "k", "linestyle": "--"}, ax=ax1)
ax1.text(0, 0.9, "prior", horizontalalignment="center")

# posterior
az.plot_kde(trace_mvse_df[("posterior", "chol_cov_corr[0,1]", 0, 1)], ax=ax1)
ax1.text(-0.35, 2.0, "posterior", horizontalalignment="center", color="blue")

ax1.set(
    xlabel="rho (correlation factor)",
    ylabel="density",
    title="Distribution of correlation values",
)
# Out:
# [Text(0.5, 0, 'rho (correlation factor)'),
#  Text(0, 0.5, 'density'),
#  Text(0.5, 1.0, 'Distribution of correlation values')]

# %% [markdown]
# # Plot predicted proportion of women using contraception for each district
#
# Scatterplot of urban vs. rural.

# %% [markdown]
# ## Sidebar: How come I can't get "p"?  (START)

# %% [markdown]
# I have trouble getting p. Why isn't it a parameter that was kept? Maybe how I setup my model?
#
# Here's how I set it up before and how I'll try to do it:
#
# ```
# # link function
# p = pm.math.invlogit(a[df_bangladesh["district_code"]])
#
# # new link function
# p = pm.Deterministic("p", pm.math.invlogit(a[df_bangladesh["district_code"]]))
# ```

# %%
# multilevel model, non-centered version
with pm.Model() as m_13_2sr2:

    # prior for average district
    a_bar = pm.Normal("a_bar", 0.0, 1.5)
    # prior for SD of districts
    sigma = pm.Exponential("sigma", 1.0)

    # alpha priors for each district
    a = pm.Normal("a", a_bar, sigma, shape=len(df_bangladesh["district_code"].unique()))

    # link function
    # p = pm.math.invlogit(a[df_bangladesh["district_code"]])

    # new link function
    p = pm.Deterministic("p", pm.math.invlogit(a[df_bangladesh["district_code"]]))

    # likelihood, n=1 since each represents an individual woman
    c = pm.Binomial("c", n=1, p=p, observed=df_bangladesh["use.contraception"])

    trace_mme2 = pm.sample(draws=1000, random_seed=19, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO:pymc3:Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# INFO:pymc3:Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a, sigma, a_bar]
# INFO:pymc3:NUTS: [a, sigma, a_bar]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 22 seconds.
# INFO:pymc3:Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 22 seconds.

# %%
az.summary(trace_mme2, var_names="p")
# Out:
#           mean     sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  ess_mean  \
# p[0]     0.272  0.039     0.214      0.337      0.000    0.000    6065.0
# p[1]     0.272  0.039     0.214      0.337      0.000    0.000    6065.0
# p[2]     0.272  0.039     0.214      0.337      0.000    0.000    6065.0
# p[3]     0.272  0.039     0.214      0.337      0.000    0.000    6065.0
# p[4]     0.272  0.039     0.214      0.337      0.000    0.000    6065.0
# ...        ...    ...       ...        ...        ...      ...       ...
# p[1929]  0.263  0.057     0.171      0.351      0.001    0.001    6079.0
# p[1930]  0.263  0.057     0.171      0.351      0.001    0.001    6079.0
# p[1931]  0.263  0.057     0.171      0.351      0.001    0.001    6079.0
# p[1932]  0.263  0.057     0.171      0.351      0.001    0.001    6079.0
# p[1933]  0.263  0.057     0.171      0.351      0.001    0.001    6079.0
#
#          ess_sd  ess_bulk  ess_tail  r_hat
# p[0]     5885.0    5973.0    2419.0    1.0
# p[1]     5885.0    5973.0    2419.0    1.0
# p[2]     5885.0    5973.0    2419.0    1.0
# p[3]     5885.0    5973.0    2419.0    1.0
# p[4]     5885.0    5973.0    2419.0    1.0
# ...         ...       ...       ...    ...
# p[1929]  5593.0    6009.0    2550.0    1.0
# p[1930]  5593.0    6009.0    2550.0    1.0
# p[1931]  5593.0    6009.0    2550.0    1.0
# p[1932]  5593.0    6009.0    2550.0    1.0
# p[1933]  5593.0    6009.0    2550.0    1.0
#
# [1934 rows x 11 columns]

# %% [markdown]
# Yes, I think the way I wrote the link function influenced whether it would be part of the posterior distribution that I can access.

# %% [markdown]
# ## Sidebar: How come I can't get "p"?  (END)

# %% [markdown]
# After the above lesson, I re-ran the model with the right implementation. Here are the posterior mean values.

# %%
df_summary_p = az.summary(trace_mvse, var_names="p")
df_summary_p
# Out:
#           mean     sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  ess_mean  \
# p[0]     0.385  0.056     0.292      0.469      0.001    0.001    1942.0
# p[1]     0.385  0.056     0.292      0.469      0.001    0.001    1942.0
# p[2]     0.385  0.056     0.292      0.469      0.001    0.001    1942.0
# p[3]     0.385  0.056     0.292      0.469      0.001    0.001    1942.0
# p[4]     0.385  0.056     0.292      0.469      0.001    0.001    1942.0
# ...        ...    ...       ...        ...        ...      ...       ...
# p[1929]  0.240  0.063     0.132      0.330      0.001    0.001    3924.0
# p[1930]  0.240  0.063     0.132      0.330      0.001    0.001    3924.0
# p[1931]  0.240  0.063     0.132      0.330      0.001    0.001    3924.0
# p[1932]  0.240  0.063     0.132      0.330      0.001    0.001    3924.0
# p[1933]  0.240  0.063     0.132      0.330      0.001    0.001    3924.0
#
#          ess_sd  ess_bulk  ess_tail  r_hat
# p[0]     1866.0    1951.0    1558.0    1.0
# p[1]     1866.0    1951.0    1558.0    1.0
# p[2]     1866.0    1951.0    1558.0    1.0
# p[3]     1866.0    1951.0    1558.0    1.0
# p[4]     1866.0    1951.0    1558.0    1.0
# ...         ...       ...       ...    ...
# p[1929]  3701.0    3912.0    2549.0    1.0
# p[1930]  3701.0    3912.0    2549.0    1.0
# p[1931]  3701.0    3912.0    2549.0    1.0
# p[1932]  3701.0    3912.0    2549.0    1.0
# p[1933]  3701.0    3912.0    2549.0    1.0
#
# [1934 rows x 11 columns]

# %%
df_bangladesh_temp = df_bangladesh.copy()
df_bangladesh_temp["post_p"] = df_summary_p.iloc[:, 0].tolist()

# %%
df_bangladesh_temp.sort_values(by=["district_code", "urban"])
# Out:
#       woman  district  use.contraception  living.children  age.centered  \
# 63       64         1                  0                4       11.4400
# 64       65         1                  0                4       -4.5599
# 65       66         1                  0                4       10.4400
# 66       67         1                  0                4        4.4400
# 67       68         1                  0                4       -3.5599
# ...     ...       ...                ...              ...           ...
# 1898   1899        61                  1                4       -3.5599
# 1899   1900        61                  0                1      -12.5600
# 1900   1901        61                  0                4       12.4400
# 1901   1902        61                  0                3        0.4400
# 1902   1903        61                  0                1       -9.5599
#
#       urban  district_code  post_p
# 63        0              0   0.181
# 64        0              0   0.181
# 65        0              0   0.181
# 66        0              0   0.181
# 67        0              0   0.181
# ...     ...            ...     ...
# 1898      1             59   0.393
# 1899      1             59   0.393
# 1900      1             59   0.393
# 1901      1             59   0.393
# 1902      1             59   0.393
#
# [1934 rows x 8 columns]

# %%
df_bangladesh_temp[df_bangladesh_temp.loc[:, "district_code"] == 0]
# Out:
#      woman  district  use.contraception  living.children  age.centered  urban  \
# 0        1         1                  0                4       18.4400      1
# 1        2         1                  0                1       -5.5599      1
# 2        3         1                  0                3        1.4400      1
# 3        4         1                  0                4        8.4400      1
# 4        5         1                  0                1      -13.5590      1
# ..     ...       ...                ...              ...           ...    ...
# 112    113         1                  0                3        3.4400      0
# 113    114         1                  0                1       -1.5599      0
# 114    115         1                  0                4        3.4400      0
# 115    116         1                  0                4       -1.5599      0
# 116    117         1                  0                3       11.4400      0
#
#      district_code  post_p
# 0                0   0.385
# 1                0   0.385
# 2                0   0.385
# 3                0   0.385
# 4                0   0.385
# ..             ...     ...
# 112              0   0.181
# 113              0   0.181
# 114              0   0.181
# 115              0   0.181
# 116              0   0.181
#
# [117 rows x 8 columns]

# %% [markdown]
# The posterior prediction is the same for each woman in the same district and urban code. We can get the fixed and multilevel model estimates this way.

# %%
df_bangladesh_temp2 = df_bangladesh_temp.groupby(["district_code", "urban"]).mean(
    "use.contraception"
)[["use.contraception", "post_p"]]

df_bangladesh_temp2.reset_index(inplace=True)

df_bangladesh_temp2.columns = [
    "district_code",
    "urban",
    "use.contraception_fixed",
    "use.contraception_mixed",
]

df_bangladesh_temp2
# Out:
#      district_code  urban  use.contraception_fixed  use.contraception_mixed
# 0                0      0                 0.129630                    0.181
# 1                0      1                 0.365079                    0.385
# 2                1      0                 0.350000                    0.342
# 3                2      1                 1.000000                    0.570
# 4                3      0                 0.263158                    0.303
# ..             ...    ...                      ...                      ...
# 97              57      0                 0.100000                    0.245
# 98              58      0                 0.181818                    0.245
# 99              58      1                 0.300000                    0.410
# 100             59      0                 0.193548                    0.240
# 101             59      1                 0.272727                    0.393
#
# [102 rows x 4 columns]

# %%
df_bangladesh_temp2["district_code"].value_counts()
# Out:
# 0     2
# 26    2
# 28    2
# 29    2
# 32    2
# 33    2
# 34    2
# 35    2
# 37    2
# 38    2
# 39    2
# 40    2
# 41    2
# 42    2
# 44    2
# 45    2
# 46    2
# 47    2
# 49    2
# 50    2
# 51    2
# 54    2
# 55    2
# 56    2
# 58    2
# 27    2
# 30    2
# 59    2
# 17    2
# 7     2
# 11    2
# 12    2
# 24    2
# 13    2
# 14    2
# 15    2
# 18    2
# 20    2
# 5     2
# 4     2
# 3     2
# 8     2
# 48    1
# 52    1
# 6     1
# 53    1
# 57    1
# 2     1
# 25    1
# 9     1
# 10    1
# 16    1
# 36    1
# 19    1
# 21    1
# 22    1
# 31    1
# 1     1
# 23    1
# 43    1
# Name: district_code, dtype: int64

# %% [markdown]
# Note that not all districts have both urban and rural so I'll just stick to those that have both.

# %%
districts_with2 = (
    df_bangladesh_temp2["district_code"]
    .value_counts()[(df_bangladesh_temp2["district_code"].value_counts() == 2)]
    .index
)

# %%
df_bangladesh_temp3 = df_bangladesh_temp2.loc[
    df_bangladesh_temp2["district_code"].isin(districts_with2), :
]

# %%
df_bangladesh_temp3.shape
# Out:
# (84, 4)

# %%
df_bangladesh_temp3["district_code"].unique()
# Out:
# array([ 0,  3,  4,  5,  7,  8, 11, 12, 13, 14, 15, 17, 18, 20, 24, 26, 27,
#        28, 29, 30, 32, 33, 34, 35, 37, 38, 39, 40, 41, 42, 44, 45, 46, 47,
#        49, 50, 51, 54, 55, 56, 58, 59])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

for district in df_bangladesh_temp3["district_code"].unique():
    bool_row_urban = (df_bangladesh_temp3["district_code"] == district) & (
        df_bangladesh_temp2["urban"] == 1
    )
    bool_row_rural = (df_bangladesh_temp3["district_code"] == district) & (
        df_bangladesh_temp2["urban"] == 0
    )

    # rural on x-xaxis and urban on y-axis to match solutions
    ax1.scatter(
        df_bangladesh_temp3.loc[bool_row_rural, "use.contraception_mixed"],
        df_bangladesh_temp3.loc[bool_row_urban, "use.contraception_mixed"],
        facecolors="none",
        edgecolors="black",
    )

ax1.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    xlabel="proportion of rural women\nusing contraception",
    ylabel="proportion of urban women\nusing contraception",
    title="mixed effects model",
)


for district in df_bangladesh_temp3["district_code"].unique():
    bool_row_urban = (df_bangladesh_temp3["district_code"] == district) & (
        df_bangladesh_temp2["urban"] == 1
    )
    bool_row_rural = (df_bangladesh_temp3["district_code"] == district) & (
        df_bangladesh_temp2["urban"] == 0
    )

    # rural on x-xaxis and urban on y-axis to match solutions
    ax2.scatter(
        df_bangladesh_temp3.loc[bool_row_rural, "use.contraception_fixed"],
        df_bangladesh_temp3.loc[bool_row_urban, "use.contraception_fixed"],
        facecolors="none",
        edgecolors="black",
    )

ax2.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    xlabel="proportion of rural women\nusing contraception",
    ylabel="proportion of urban women\nusing contraception",
    title="fixed effects model",
)
# Out:
# [(-0.05, 1.05),
#  (-0.05, 1.05),
#  Text(0.5, 0, 'proportion of rural women\nusing contraception'),
#  Text(0, 0.5, 'proportion of urban women\nusing contraception'),
#  Text(0.5, 1.0, 'fixed effects model')]

# %% [markdown]
# Note how the mixed effects model imposes a lot of shrinkage by accounting for the sample size differences with each district.

# %% [markdown]
# # Comparing with online solutions

# %% [markdown]
# I got largely the same results. I could've also looked at the \(\alpha\) and \(\beta\) averages for a quicker snapshot. There's also some more explanation in terms of interpretation: "Since the slope is the difference between urban and non-urban areas, you can see this as saying that districts with high use in rural areas
# have urban areas that aren’t as different."

# %% [markdown]
# Appendix: Environment and system parameters

# %%
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Fri Jul 02 2021
#
# Python implementation: CPython
# Python version       : 3.8.6
# IPython version      : 7.20.0
#
# pandas    : 1.2.1
# matplotlib: 3.3.4
# arviz     : 0.11.1
# pymc3     : 3.11.0
# daft      : 0.1.0
# json      : 2.0.9
# numpy     : 1.20.1
# seaborn   : 0.11.1
# scipy     : 1.6.0
#
# Watermark: 2.1.0
